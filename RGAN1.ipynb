# %% [markdown]
# <a href="https://colab.research.google.com/github/alyahoang99/GANs/blob/main/RGAN1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import time
from tensorflow.keras import layers, models

# %%
FEATURE_DIM = 3
LATENT_DIM = 100
GRU_UNITS = 128
BATCH_SIZE = 100
EPOCHS = 500
GEN_LR = 2e-5
DISC_LR = 1e-5
BETA_1 = 0.5
DISC_UPDATES_PER_GEN = 6
LAMBDA_GP = 12.0
SEQ_LEN = 7  # Sequence length for the time steps

# %%
# =================== Data Preprocessing ===================
# data preprocess
# Load dataset
# Load smart meter data (Timestamp, Value, Value_HeatPump, Value_OtherAppliances)
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/GANs/resampleddata (1).csv', parse_dates=['Timestamp'])
df.set_index('Timestamp', inplace=True)

# Select relevant features
features = ['Value', 'Value_HeatPump', 'Value_OtherAppliances']
data = df[features].values.astype(np.float32)

# Normalize data to [0, 1] for tanh
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

def create_sequences(data, seq_len, batchsize):
    sequences = []
    for i in range(len(data) - seq_len + 1):
        seq = data[i:i + seq_len]
        if len(seq) == seq_len:
            sequences.append(seq)
    return np.array(sequences)

real_sequences = create_sequences(data, SEQ_LEN, BATCH_SIZE)
print("Sequence data shape:", real_sequences.shape)  # (num_samples, 7, 3)
# Out:
# Sequence data shape: (1011, 7, 3)

# %%
BUFFER_SIZE = 1000  # Optional, for shuffling

dataset = tf.data.Dataset.from_tensor_slices(real_sequences)
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# %%
dataset
# Out:
# <_BatchDataset element_spec=TensorSpec(shape=(100, 7, 3), dtype=tf.float32, name=None)>

# %%
from tensorflow.keras import layers

def attention_block(inputs):
    # Score computation
    scores = layers.Dense(inputs.shape[-1], activation='tanh')(inputs)
    weights = layers.Softmax(axis=1)(scores)

    # Context vector as weighted sum
    context = layers.Multiply()([weights, inputs])
    context = layers.Lambda(lambda x: tf.reduce_sum(x, axis=1))(context)
    return context

# %%
# =================== Generator ===================
def build_generator():
    z = layers.Input(shape=(SEQ_LEN, LATENT_DIM))
    x = layers.GRU(GRU_UNITS, return_sequences=True)(z)
    x = layers.GRU(GRU_UNITS, return_sequences=True)(x)
    x = layers.TimeDistributed(layers.Dense(GRU_UNITS, activation='gelu'))(x)
    x = layers.TimeDistributed(layers.Dense(FEATURE_DIM))(x)
    return models.Model(z, x, name="Generator")

# =================== Discriminator ===================
def build_discriminator():
    x_in = layers.Input(shape=(SEQ_LEN, FEATURE_DIM))
    x = layers.LSTM(GRU_UNITS, return_sequences=True)(x_in)
    x = attention_block(x)
    x = layers.Dense(GRU_UNITS, activation='tanh')(x)
    out = layers.Dense(1)(x)  # Linear output for WGAN
    return models.Model(x_in, out, name="Discriminator")

# %%
# =================== Gradient Penalty ===================
def gradient_penalty(discriminator, real, fake):
    alpha = tf.random.uniform([real.shape[0], 1, 1], 0., 1.)
    interpolated = alpha * real + (1 - alpha) * fake
    with tf.GradientTape() as tape:
        tape.watch(interpolated)
        pred = discriminator(interpolated)
    grads = tape.gradient(pred, interpolated)
    norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2]) + 1e-12)
    return tf.reduce_mean((norm - 1.0) ** 2)

# %%
# =================== Training Step ===================
def train_step(generator, discriminator, real_batch, gen_opt, disc_opt):
    batch_size = tf.shape(real_batch)[0]
    for _ in range(DISC_UPDATES_PER_GEN):
        noise = tf.random.normal([batch_size, SEQ_LEN, LATENT_DIM])
        with tf.GradientTape() as tape:
            fake = generator(noise)
            d_real = discriminator(real_batch)
            d_fake = discriminator(fake)
            gp = gradient_penalty(discriminator, real_batch, fake)
            wasserstein_distance = tf.reduce_mean(d_real) - tf.reduce_mean(d_fake)
            d_loss = tf.reduce_mean(d_fake) - tf.reduce_mean(d_real) + LAMBDA_GP * gp
        grads = tape.gradient(d_loss, discriminator.trainable_variables)
        disc_opt.apply_gradients(zip(grads, discriminator.trainable_variables))

    noise = tf.random.normal([batch_size, SEQ_LEN, LATENT_DIM])
    with tf.GradientTape() as tape:
        fake = generator(noise)
        d_fake = discriminator(fake)
        g_loss = -tf.reduce_mean(d_fake)
    grads = tape.gradient(g_loss, generator.trainable_variables)
    gen_opt.apply_gradients(zip(grads, generator.trainable_variables))

    return d_loss, g_loss, wasserstein_distance

# %%
generator = build_generator()
discriminator = build_discriminator()
gen_opt = tf.keras.optimizers.Adam(GEN_LR, beta_1=BETA_1)
disc_opt = tf.keras.optimizers.Adam(DISC_LR, beta_1=BETA_1)

# %%
# =================== Training Loop ===================
def train(dataset, epochs):
    d_loss_hist, g_loss_hist, wasserstein_hist = [], [], []

    for epoch in range(epochs):
        start = time.time()
        d_losses, g_losses, w_distances = [], [], []

        for real_batch in dataset:

            d_loss, g_loss, w_distance = train_step(generator, discriminator, real_batch, gen_opt, disc_opt)
            d_losses.append(d_loss.numpy())
            g_losses.append(g_loss.numpy())
            w_distances.append(w_distance.numpy())

        d_loss_mean = np.mean(d_losses)
        g_loss_mean = np.mean(g_losses)
        w_distance_mean = np.mean(w_distances)
        d_loss_hist.append(d_loss_mean)
        g_loss_hist.append(g_loss_mean)
        wasserstein_hist.append(w_distance_mean)

        print(f"Epoch {epoch+1}, D Loss: {d_loss_mean:.4f}, G Loss: {g_loss_mean:.4f}, W-dist: {w_distance_mean:.4f}, Time: {time.time() - start:.2f}s")

    print("Training finished.")

    return d_losses, g_losses, w_distances

# %%
def train(dataset, epochs):
    d_loss_hist, g_loss_hist, wasserstein_hist = [], [], []

    for epoch in range(epochs):
        start = time.time()
        d_losses, g_losses, w_distances = [], [], []

        for real_batch in dataset:
            d_loss, g_loss, w_distance = train_step(generator, discriminator, real_batch, gen_opt, disc_opt)
            d_losses.append(d_loss.numpy())
            g_losses.append(g_loss.numpy())
            w_distances.append(w_distance.numpy())

        d_loss_mean = np.mean(d_losses)
        g_loss_mean = np.mean(g_losses)
        w_distance_mean = np.mean(w_distances)
        d_loss_hist.append(d_loss_mean)
        g_loss_hist.append(g_loss_mean)
        wasserstein_hist.append(w_distance_mean)

        print(f"Epoch {epoch+1}, D Loss: {d_loss_mean:.4f}, G Loss: {g_loss_mean:.4f}, W-dist: {w_distance_mean:.4f}, Time: {time.time() - start:.2f}s")

    print("Training finished.")

    return d_loss_hist, g_loss_hist, wasserstein_hist  # <-- Return the histories

# %%
d_loss_hist, g_loss_hist, wasserstein_hist = train(dataset, epochs=EPOCHS)
# Out:
# Epoch 1, D Loss: 10.4367, G Loss: 0.0019, W-dist: 0.0738, Time: 81.68s
# Epoch 2, D Loss: 9.8611, G Loss: 0.0050, W-dist: 0.0990, Time: 81.90s
# Epoch 3, D Loss: 9.2655, G Loss: 0.0065, W-dist: 0.1261, Time: 58.99s
# Epoch 4, D Loss: 8.6351, G Loss: 0.0069, W-dist: 0.1557, Time: 57.74s
# Epoch 5, D Loss: 7.9636, G Loss: 0.0033, W-dist: 0.1846, Time: 81.90s
# Epoch 6, D Loss: 7.2291, G Loss: 0.0005, W-dist: 0.2178, Time: 58.45s
# Epoch 7, D Loss: 6.4292, G Loss: -0.0153, W-dist: 0.2507, Time: 58.48s
# Epoch 8, D Loss: 5.5526, G Loss: -0.0346, W-dist: 0.2882, Time: 81.90s
# Epoch 9, D Loss: 4.6024, G Loss: -0.0608, W-dist: 0.3296, Time: 57.91s
# Epoch 10, D Loss: 3.5624, G Loss: -0.1022, W-dist: 0.3766, Time: 81.90s
# Epoch 11, D Loss: 2.4758, G Loss: -0.1601, W-dist: 0.4393, Time: 81.91s
# Epoch 12, D Loss: 1.4378, G Loss: -0.2352, W-dist: 0.4916, Time: 81.90s
# Epoch 13, D Loss: 0.5145, G Loss: -0.3272, W-dist: 0.5719, Time: 81.90s
# Epoch 14, D Loss: -0.1453, G Loss: -0.4409, W-dist: 0.6241, Time: 60.20s
# Epoch 15, D Loss: -0.4720, G Loss: -0.5457, W-dist: 0.6616, Time: 58.73s
# Epoch 16, D Loss: -0.5487, G Loss: -0.6264, W-dist: 0.6527, Time: 58.14s
# Epoch 17, D Loss: -0.5146, G Loss: -0.7802, W-dist: 0.6027, Time: 59.50s
# Epoch 18, D Loss: -0.4521, G Loss: -0.8788, W-dist: 0.5410, Time: 81.90s
# Epoch 19, D Loss: -0.3563, G Loss: -0.9805, W-dist: 0.4376, Time: 58.67s
# Epoch 20, D Loss: -0.2568, G Loss: -1.1143, W-dist: 0.3242, Time: 62.02s
# Epoch 21, D Loss: -0.1419, G Loss: -1.2179, W-dist: 0.2034, Time: 59.08s
# Epoch 22, D Loss: -0.0211, G Loss: -1.3775, W-dist: 0.0729, Time: 58.85s
# Epoch 23, D Loss: 0.1155, G Loss: -1.5288, W-dist: -0.0751, Time: 60.81s
# Epoch 24, D Loss: 0.2794, G Loss: -1.7148, W-dist: -0.2460, Time: 58.40s
# Epoch 25, D Loss: 0.4431, G Loss: -1.8626, W-dist: -0.4161, Time: 59.18s
# Epoch 26, D Loss: 0.6310, G Loss: -2.0469, W-dist: -0.6046, Time: 59.43s
# Epoch 27, D Loss: 0.8315, G Loss: -2.2400, W-dist: -0.7956, Time: 59.89s
# Epoch 28, D Loss: 1.0371, G Loss: -2.5051, W-dist: -0.9937, Time: 57.99s
# Epoch 29, D Loss: 1.2941, G Loss: -2.7139, W-dist: -1.2306, Time: 58.00s
# Epoch 30, D Loss: 1.4349, G Loss: -2.9043, W-dist: -1.3416, Time: 59.25s
# Epoch 31, D Loss: 1.6987, G Loss: -3.0694, W-dist: -1.5530, Time: 58.53s
# Epoch 32, D Loss: 1.8724, G Loss: -3.2194, W-dist: -1.6708, Time: 81.90s
# Epoch 33, D Loss: 2.0233, G Loss: -3.4191, W-dist: -1.7952, Time: 81.90s
# Epoch 34, D Loss: 2.1898, G Loss: -3.4723, W-dist: -1.8987, Time: 57.99s
# Epoch 35, D Loss: 2.2709, G Loss: -3.5153, W-dist: -1.9246, Time: 58.28s
# Epoch 36, D Loss: 2.2922, G Loss: -3.5678, W-dist: -1.9305, Time: 61.13s
# Epoch 37, D Loss: 2.3275, G Loss: -3.5757, W-dist: -1.9323, Time: 58.24s
# Epoch 38, D Loss: 2.2765, G Loss: -3.4511, W-dist: -1.8417, Time: 58.36s
# Epoch 39, D Loss: 2.1887, G Loss: -3.3752, W-dist: -1.7391, Time: 58.05s
# Epoch 40, D Loss: 1.9893, G Loss: -3.2359, W-dist: -1.5646, Time: 58.21s
# Epoch 41, D Loss: 1.7610, G Loss: -3.0456, W-dist: -1.3597, Time: 59.66s
# Epoch 42, D Loss: 1.5477, G Loss: -2.8392, W-dist: -1.1564, Time: 59.90s
# Epoch 43, D Loss: 1.2755, G Loss: -2.6647, W-dist: -0.9308, Time: 59.00s
# Epoch 44, D Loss: 1.0276, G Loss: -2.3864, W-dist: -0.6945, Time: 58.77s
# Epoch 45, D Loss: 0.7282, G Loss: -2.1449, W-dist: -0.4225, Time: 58.41s
# Epoch 46, D Loss: 0.4769, G Loss: -1.9001, W-dist: -0.1827, Time: 60.53s
# Epoch 47, D Loss: 0.2191, G Loss: -1.6368, W-dist: 0.0712, Time: 58.71s
# Epoch 48, D Loss: -0.0537, G Loss: -1.4165, W-dist: 0.3361, Time: 57.83s
# Epoch 49, D Loss: -0.2895, G Loss: -1.1496, W-dist: 0.5402, Time: 59.26s
# Epoch 50, D Loss: -0.5468, G Loss: -0.9071, W-dist: 0.7620, Time: 57.65s
# Epoch 51, D Loss: -0.7524, G Loss: -0.7109, W-dist: 0.9350, Time: 81.90s
# Epoch 52, D Loss: -0.9513, G Loss: -0.4799, W-dist: 1.1234, Time: 81.90s
# Epoch 53, D Loss: -1.1564, G Loss: -0.2536, W-dist: 1.3033, Time: 58.05s
# Epoch 54, D Loss: -1.3034, G Loss: -0.0470, W-dist: 1.4045, Time: 60.42s
# Epoch 55, D Loss: -1.3782, G Loss: 0.1024, W-dist: 1.4614, Time: 58.32s
# Epoch 56, D Loss: -1.4705, G Loss: 0.3145, W-dist: 1.5398, Time: 57.71s
# Epoch 57, D Loss: -1.4822, G Loss: 0.4622, W-dist: 1.5432, Time: 81.90s
# Epoch 58, D Loss: -1.4033, G Loss: 0.4862, W-dist: 1.4650, Time: 59.83s
# Epoch 59, D Loss: -1.3050, G Loss: 0.4956, W-dist: 1.3760, Time: 58.58s
# Epoch 60, D Loss: -1.1563, G Loss: 0.4538, W-dist: 1.2354, Time: 81.91s
# Epoch 61, D Loss: -1.0358, G Loss: 0.2991, W-dist: 1.1088, Time: 59.04s
# Epoch 62, D Loss: -0.9045, G Loss: 0.1919, W-dist: 0.9655, Time: 81.90s
# Epoch 63, D Loss: -0.7953, G Loss: 0.0441, W-dist: 0.8442, Time: 81.91s
# Epoch 64, D Loss: -0.6776, G Loss: -0.0495, W-dist: 0.7147, Time: 60.10s
# Epoch 65, D Loss: -0.5949, G Loss: -0.1982, W-dist: 0.6239, Time: 62.98s
# Epoch 66, D Loss: -0.5009, G Loss: -0.2519, W-dist: 0.5221, Time: 58.75s
# Epoch 67, D Loss: -0.4564, G Loss: -0.3591, W-dist: 0.4685, Time: 59.13s
# Epoch 68, D Loss: -0.3841, G Loss: -0.4079, W-dist: 0.3959, Time: 58.89s
# Epoch 69, D Loss: -0.3423, G Loss: -0.4695, W-dist: 0.3515, Time: 81.90s
# Epoch 70, D Loss: -0.3187, G Loss: -0.4983, W-dist: 0.3259, Time: 59.17s
# Epoch 71, D Loss: -0.2833, G Loss: -0.5308, W-dist: 0.2909, Time: 59.54s
# Epoch 72, D Loss: -0.2851, G Loss: -0.5728, W-dist: 0.2932, Time: 58.53s
# Epoch 73, D Loss: -0.2810, G Loss: -0.5788, W-dist: 0.2906, Time: 58.47s
# Epoch 74, D Loss: -0.2701, G Loss: -0.5828, W-dist: 0.2806, Time: 59.30s
# Epoch 75, D Loss: -0.2752, G Loss: -0.5953, W-dist: 0.2871, Time: 81.91s
# Epoch 76, D Loss: -0.2778, G Loss: -0.5855, W-dist: 0.2926, Time: 81.90s
# Epoch 77, D Loss: -0.2849, G Loss: -0.6162, W-dist: 0.3027, Time: 57.29s
# Epoch 78, D Loss: -0.2878, G Loss: -0.6348, W-dist: 0.3101, Time: 81.90s
# Epoch 79, D Loss: -0.2968, G Loss: -0.6583, W-dist: 0.3193, Time: 81.90s
# Epoch 80, D Loss: -0.2919, G Loss: -0.6802, W-dist: 0.3181, Time: 81.91s
# Epoch 81, D Loss: -0.3062, G Loss: -0.6936, W-dist: 0.3329, Time: 81.90s
# Epoch 82, D Loss: -0.3146, G Loss: -0.7297, W-dist: 0.3425, Time: 57.09s
# Epoch 83, D Loss: -0.3126, G Loss: -0.7457, W-dist: 0.3421, Time: 56.71s
# Epoch 84, D Loss: -0.3137, G Loss: -0.7698, W-dist: 0.3419, Time: 81.90s
# Epoch 85, D Loss: -0.3218, G Loss: -0.8080, W-dist: 0.3501, Time: 57.15s
# Epoch 86, D Loss: -0.3294, G Loss: -0.8254, W-dist: 0.3579, Time: 81.90s
# Epoch 87, D Loss: -0.3278, G Loss: -0.8566, W-dist: 0.3557, Time: 81.90s
# Epoch 88, D Loss: -0.3349, G Loss: -0.8842, W-dist: 0.3629, Time: 61.06s
# Epoch 89, D Loss: -0.3377, G Loss: -0.9012, W-dist: 0.3656, Time: 58.71s
# Epoch 90, D Loss: -0.3506, G Loss: -0.9197, W-dist: 0.3771, Time: 58.53s
# Epoch 91, D Loss: -0.3457, G Loss: -0.9418, W-dist: 0.3710, Time: 60.01s
# Epoch 92, D Loss: -0.3505, G Loss: -0.9824, W-dist: 0.3771, Time: 58.25s
# Epoch 93, D Loss: -0.3523, G Loss: -0.9845, W-dist: 0.3798, Time: 81.90s
# Epoch 94, D Loss: -0.3602, G Loss: -1.0084, W-dist: 0.3856, Time: 81.90s
# Epoch 95, D Loss: -0.3552, G Loss: -1.0355, W-dist: 0.3790, Time: 56.66s
# Epoch 96, D Loss: -0.3442, G Loss: -1.0487, W-dist: 0.3680, Time: 56.73s
# Epoch 97, D Loss: -0.3525, G Loss: -1.0706, W-dist: 0.3755, Time: 81.90s
# Epoch 98, D Loss: -0.3548, G Loss: -1.0837, W-dist: 0.3761, Time: 81.90s
# Epoch 99, D Loss: -0.3407, G Loss: -1.1091, W-dist: 0.3615, Time: 59.54s
# Epoch 100, D Loss: -0.3512, G Loss: -1.1171, W-dist: 0.3717, Time: 57.08s
# Epoch 101, D Loss: -0.3457, G Loss: -1.1426, W-dist: 0.3657, Time: 56.84s
# Epoch 102, D Loss: -0.3369, G Loss: -1.1608, W-dist: 0.3567, Time: 58.37s
# Epoch 103, D Loss: -0.3306, G Loss: -1.1776, W-dist: 0.3498, Time: 56.72s
# Epoch 104, D Loss: -0.3360, G Loss: -1.1970, W-dist: 0.3533, Time: 57.34s
# Epoch 105, D Loss: -0.3235, G Loss: -1.2043, W-dist: 0.3409, Time: 58.75s
# Epoch 106, D Loss: -0.3242, G Loss: -1.2201, W-dist: 0.3430, Time: 57.28s
# Epoch 107, D Loss: -0.3275, G Loss: -1.2292, W-dist: 0.3447, Time: 57.01s
# Epoch 108, D Loss: -0.3183, G Loss: -1.2515, W-dist: 0.3347, Time: 81.90s
# Epoch 109, D Loss: -0.3160, G Loss: -1.2523, W-dist: 0.3326, Time: 57.54s
# Epoch 110, D Loss: -0.3094, G Loss: -1.2687, W-dist: 0.3255, Time: 81.90s
# Epoch 111, D Loss: -0.2934, G Loss: -1.2903, W-dist: 0.3095, Time: 56.40s
# Epoch 112, D Loss: -0.2975, G Loss: -1.2949, W-dist: 0.3125, Time: 81.90s
# Epoch 113, D Loss: -0.2823, G Loss: -1.3004, W-dist: 0.2981, Time: 81.90s
# Epoch 114, D Loss: -0.2779, G Loss: -1.3059, W-dist: 0.2924, Time: 81.90s
# Epoch 115, D Loss: -0.2823, G Loss: -1.3061, W-dist: 0.2984, Time: 81.90s
# Epoch 116, D Loss: -0.2724, G Loss: -1.3154, W-dist: 0.2872, Time: 56.98s
# Epoch 117, D Loss: -0.2804, G Loss: -1.3136, W-dist: 0.2960, Time: 58.62s
# Epoch 118, D Loss: -0.2712, G Loss: -1.3192, W-dist: 0.2866, Time: 57.13s
# Epoch 119, D Loss: -0.2574, G Loss: -1.3141, W-dist: 0.2729, Time: 56.87s
# Epoch 120, D Loss: -0.2693, G Loss: -1.3027, W-dist: 0.2851, Time: 58.78s
# Epoch 121, D Loss: -0.2447, G Loss: -1.3079, W-dist: 0.2610, Time: 57.46s
# Epoch 122, D Loss: -0.2389, G Loss: -1.2979, W-dist: 0.2546, Time: 57.13s
# Epoch 123, D Loss: -0.2503, G Loss: -1.3019, W-dist: 0.2687, Time: 81.91s
# Epoch 124, D Loss: -0.2432, G Loss: -1.2795, W-dist: 0.2619, Time: 56.81s
# Epoch 125, D Loss: -0.2483, G Loss: -1.2657, W-dist: 0.2662, Time: 81.90s
# Epoch 126, D Loss: -0.2571, G Loss: -1.2622, W-dist: 0.2767, Time: 81.91s
# Epoch 127, D Loss: -0.2464, G Loss: -1.2612, W-dist: 0.2649, Time: 81.90s
# Epoch 128, D Loss: -0.2503, G Loss: -1.2359, W-dist: 0.2722, Time: 56.44s
# Epoch 129, D Loss: -0.2478, G Loss: -1.2389, W-dist: 0.2704, Time: 81.90s
# Epoch 130, D Loss: -0.2487, G Loss: -1.2153, W-dist: 0.2701, Time: 56.65s
# Epoch 131, D Loss: -0.2314, G Loss: -1.2166, W-dist: 0.2542, Time: 57.70s
# Epoch 132, D Loss: -0.2484, G Loss: -1.2114, W-dist: 0.2763, Time: 58.39s
# Epoch 133, D Loss: -0.2265, G Loss: -1.2028, W-dist: 0.2547, Time: 56.71s
# Epoch 134, D Loss: -0.2188, G Loss: -1.2132, W-dist: 0.2495, Time: 57.07s
# Epoch 135, D Loss: -0.2199, G Loss: -1.2264, W-dist: 0.2503, Time: 57.94s
# Epoch 136, D Loss: -0.2132, G Loss: -1.2502, W-dist: 0.2477, Time: 56.63s
# Epoch 137, D Loss: -0.1979, G Loss: -1.2568, W-dist: 0.2391, Time: 57.04s
# Epoch 138, D Loss: -0.1748, G Loss: -1.3155, W-dist: 0.2199, Time: 58.31s
# Epoch 139, D Loss: -0.1679, G Loss: -1.3655, W-dist: 0.2128, Time: 57.07s
# Epoch 140, D Loss: -0.1496, G Loss: -1.4230, W-dist: 0.1983, Time: 57.20s
# Epoch 141, D Loss: -0.1230, G Loss: -1.4954, W-dist: 0.1824, Time: 59.19s
# Epoch 142, D Loss: -0.0956, G Loss: -1.5507, W-dist: 0.1880, Time: 81.90s
# Epoch 143, D Loss: -0.1056, G Loss: -1.6251, W-dist: 0.1830, Time: 81.91s
# Epoch 144, D Loss: -0.1111, G Loss: -1.6800, W-dist: 0.1809, Time: 81.91s
# Epoch 145, D Loss: -0.1028, G Loss: -1.7387, W-dist: 0.1737, Time: 81.90s
# Epoch 146, D Loss: -0.1048, G Loss: -1.7981, W-dist: 0.1790, Time: 58.59s
# Epoch 147, D Loss: -0.1223, G Loss: -1.8263, W-dist: 0.1959, Time: 56.82s
# Epoch 148, D Loss: -0.1418, G Loss: -1.8851, W-dist: 0.2031, Time: 56.84s
# Epoch 149, D Loss: -0.1353, G Loss: -1.9233, W-dist: 0.1980, Time: 58.69s
# Epoch 150, D Loss: -0.1236, G Loss: -1.9711, W-dist: 0.1768, Time: 57.16s
# Epoch 151, D Loss: -0.1238, G Loss: -2.0012, W-dist: 0.1758, Time: 56.73s
# Epoch 152, D Loss: -0.0845, G Loss: -2.0599, W-dist: 0.1273, Time: 58.37s
# Epoch 153, D Loss: -0.0816, G Loss: -2.0928, W-dist: 0.1293, Time: 81.91s
# Epoch 154, D Loss: -0.0683, G Loss: -2.1021, W-dist: 0.1049, Time: 58.23s
# Epoch 155, D Loss: -0.0081, G Loss: -2.1545, W-dist: 0.0508, Time: 56.78s
# Epoch 156, D Loss: -0.0061, G Loss: -2.1970, W-dist: 0.0461, Time: 57.23s
# Epoch 157, D Loss: 0.0205, G Loss: -2.1831, W-dist: 0.0128, Time: 58.64s
# Epoch 158, D Loss: 0.0173, G Loss: -2.1638, W-dist: 0.0164, Time: 81.90s
# Epoch 159, D Loss: 0.0408, G Loss: -2.1267, W-dist: -0.0088, Time: 81.90s
# Epoch 160, D Loss: 0.0206, G Loss: -2.0510, W-dist: 0.0132, Time: 59.20s
# Epoch 161, D Loss: 0.0126, G Loss: -1.8952, W-dist: 0.0202, Time: 56.83s
# Epoch 162, D Loss: -0.0308, G Loss: -1.6525, W-dist: 0.0651, Time: 56.70s
# Epoch 163, D Loss: -0.1003, G Loss: -1.2715, W-dist: 0.1279, Time: 57.97s
# Epoch 164, D Loss: -0.1494, G Loss: -0.8013, W-dist: 0.1826, Time: 56.78s
# Epoch 165, D Loss: -0.1479, G Loss: -0.4618, W-dist: 0.1821, Time: 56.56s
# Epoch 166, D Loss: -0.1012, G Loss: -0.3041, W-dist: 0.1280, Time: 59.07s
# Epoch 167, D Loss: -0.0285, G Loss: -0.2710, W-dist: 0.0483, Time: 57.22s
# Epoch 168, D Loss: 0.0324, G Loss: -0.3301, W-dist: -0.0174, Time: 56.99s
# Epoch 169, D Loss: 0.1537, G Loss: -0.4712, W-dist: -0.1343, Time: 59.47s
# Epoch 170, D Loss: 0.2190, G Loss: -0.6461, W-dist: -0.2006, Time: 81.90s
# Epoch 171, D Loss: 0.2449, G Loss: -0.7886, W-dist: -0.2209, Time: 81.90s
# Epoch 172, D Loss: 0.2643, G Loss: -0.9509, W-dist: -0.2325, Time: 81.90s
# Epoch 173, D Loss: 0.2885, G Loss: -1.1102, W-dist: -0.2457, Time: 56.95s
# Epoch 174, D Loss: 0.2585, G Loss: -1.2455, W-dist: -0.1997, Time: 58.65s
# Epoch 175, D Loss: 0.2416, G Loss: -1.3717, W-dist: -0.1691, Time: 56.44s
# Epoch 176, D Loss: 0.2223, G Loss: -1.5535, W-dist: -0.1221, Time: 56.82s
# Epoch 177, D Loss: 0.1647, G Loss: -1.7889, W-dist: -0.0464, Time: 58.53s
# Epoch 178, D Loss: 0.0703, G Loss: -2.0112, W-dist: 0.0454, Time: 56.46s
# Epoch 179, D Loss: -0.0389, G Loss: -2.1932, W-dist: 0.1287, Time: 56.75s
# Epoch 180, D Loss: -0.0822, G Loss: -2.3445, W-dist: 0.1581, Time: 56.55s
# Epoch 181, D Loss: -0.1164, G Loss: -2.4934, W-dist: 0.1913, Time: 57.31s
# Epoch 182, D Loss: -0.0813, G Loss: -2.5596, W-dist: 0.1396, Time: 57.01s
# Epoch 183, D Loss: -0.0776, G Loss: -2.5898, W-dist: 0.1340, Time: 56.98s
# Epoch 184, D Loss: -0.0526, G Loss: -2.5851, W-dist: 0.0967, Time: 81.90s
# Epoch 185, D Loss: -0.0963, G Loss: -2.4193, W-dist: 0.1342, Time: 81.91s
# Epoch 186, D Loss: -0.2223, G Loss: -1.9849, W-dist: 0.2475, Time: 81.90s
# Epoch 187, D Loss: -0.3535, G Loss: -1.1971, W-dist: 0.3883, Time: 56.01s
# Epoch 188, D Loss: -0.3775, G Loss: -0.6658, W-dist: 0.4381, Time: 58.34s
# Epoch 189, D Loss: -0.3808, G Loss: -0.3889, W-dist: 0.4295, Time: 59.55s
# Epoch 190, D Loss: -0.3753, G Loss: -0.2278, W-dist: 0.4205, Time: 57.35s
# Epoch 191, D Loss: -0.3278, G Loss: -0.0809, W-dist: 0.3685, Time: 57.47s
# Epoch 192, D Loss: -0.2739, G Loss: -0.0250, W-dist: 0.3198, Time: 57.32s
# Epoch 193, D Loss: -0.2084, G Loss: -0.0684, W-dist: 0.2453, Time: 58.33s
# Epoch 194, D Loss: -0.1381, G Loss: -0.0472, W-dist: 0.1814, Time: 81.90s
# Epoch 195, D Loss: -0.0641, G Loss: -0.0907, W-dist: 0.1034, Time: 81.90s
# Epoch 196, D Loss: -0.0221, G Loss: -0.1939, W-dist: 0.0645, Time: 57.77s
# Epoch 197, D Loss: -0.0190, G Loss: -0.2347, W-dist: 0.0510, Time: 81.90s
# Epoch 198, D Loss: 0.0108, G Loss: -0.3286, W-dist: 0.0272, Time: 59.31s
# Epoch 199, D Loss: 0.0387, G Loss: -0.4370, W-dist: -0.0053, Time: 57.71s
# Epoch 200, D Loss: 0.0458, G Loss: -0.6025, W-dist: -0.0096, Time: 57.28s
# Epoch 201, D Loss: -0.0228, G Loss: -0.8097, W-dist: 0.0453, Time: 58.86s
# Epoch 202, D Loss: -0.0126, G Loss: -1.0355, W-dist: 0.0409, Time: 57.07s
# Epoch 203, D Loss: -0.0436, G Loss: -1.3036, W-dist: 0.0620, Time: 57.08s
# Epoch 204, D Loss: -0.0570, G Loss: -1.4180, W-dist: 0.0762, Time: 58.02s
# Epoch 205, D Loss: -0.0525, G Loss: -1.5692, W-dist: 0.0644, Time: 60.35s
# Epoch 206, D Loss: -0.0538, G Loss: -1.5872, W-dist: 0.0639, Time: 58.90s
# Epoch 207, D Loss: -0.0867, G Loss: -1.5396, W-dist: 0.0977, Time: 57.75s
# Epoch 208, D Loss: -0.0943, G Loss: -1.4230, W-dist: 0.1054, Time: 59.17s
# Epoch 209, D Loss: -0.1331, G Loss: -1.3314, W-dist: 0.1457, Time: 57.00s
# Epoch 210, D Loss: -0.1427, G Loss: -1.1644, W-dist: 0.1561, Time: 57.45s
# Epoch 211, D Loss: -0.1804, G Loss: -1.0000, W-dist: 0.1964, Time: 57.30s
# Epoch 212, D Loss: -0.2558, G Loss: -0.9147, W-dist: 0.2686, Time: 58.78s
# Epoch 213, D Loss: -0.2835, G Loss: -0.7807, W-dist: 0.3028, Time: 56.86s
# Epoch 214, D Loss: -0.3071, G Loss: -0.7005, W-dist: 0.3205, Time: 56.97s
# Epoch 215, D Loss: -0.3354, G Loss: -0.6593, W-dist: 0.3522, Time: 59.22s
# Epoch 216, D Loss: -0.3475, G Loss: -0.6030, W-dist: 0.3590, Time: 81.90s
# Epoch 217, D Loss: -0.3534, G Loss: -0.5947, W-dist: 0.3661, Time: 57.51s
# Epoch 218, D Loss: -0.3322, G Loss: -0.6091, W-dist: 0.3414, Time: 58.70s
# Epoch 219, D Loss: -0.3266, G Loss: -0.7315, W-dist: 0.3380, Time: 56.93s
# Epoch 220, D Loss: -0.3236, G Loss: -0.7700, W-dist: 0.3345, Time: 56.66s
# Epoch 221, D Loss: -0.3059, G Loss: -0.8716, W-dist: 0.3167, Time: 56.48s
# Epoch 222, D Loss: -0.2895, G Loss: -0.8602, W-dist: 0.3026, Time: 58.29s
# Epoch 223, D Loss: -0.2809, G Loss: -0.9560, W-dist: 0.2916, Time: 56.98s
# Epoch 224, D Loss: -0.2661, G Loss: -1.0228, W-dist: 0.2770, Time: 57.13s
# Epoch 225, D Loss: -0.2293, G Loss: -1.0057, W-dist: 0.2389, Time: 58.47s
# Epoch 226, D Loss: -0.2036, G Loss: -1.0530, W-dist: 0.2174, Time: 57.31s
# Epoch 227, D Loss: -0.1852, G Loss: -0.9565, W-dist: 0.1980, Time: 81.90s
# Epoch 228, D Loss: -0.1649, G Loss: -1.0076, W-dist: 0.1794, Time: 59.01s
# Epoch 229, D Loss: -0.1379, G Loss: -1.0224, W-dist: 0.1514, Time: 57.30s
# Epoch 230, D Loss: -0.1244, G Loss: -1.0406, W-dist: 0.1440, Time: 56.80s
# Epoch 231, D Loss: -0.1068, G Loss: -1.0222, W-dist: 0.1276, Time: 56.92s
# Epoch 232, D Loss: -0.0879, G Loss: -1.0359, W-dist: 0.1128, Time: 81.90s
# Epoch 233, D Loss: -0.0717, G Loss: -1.0084, W-dist: 0.1085, Time: 56.83s
# Epoch 234, D Loss: -0.0815, G Loss: -0.9839, W-dist: 0.1172, Time: 57.01s
# Epoch 235, D Loss: -0.0953, G Loss: -0.8938, W-dist: 0.1308, Time: 58.76s
# Epoch 236, D Loss: -0.1000, G Loss: -0.8405, W-dist: 0.1399, Time: 57.34s
# Epoch 237, D Loss: -0.1006, G Loss: -0.8401, W-dist: 0.1549, Time: 57.50s
# Epoch 238, D Loss: -0.1105, G Loss: -0.8388, W-dist: 0.1674, Time: 57.47s
# Epoch 239, D Loss: -0.1166, G Loss: -0.8857, W-dist: 0.1766, Time: 81.90s
# Epoch 240, D Loss: -0.1391, G Loss: -0.9940, W-dist: 0.2054, Time: 57.12s
# Epoch 241, D Loss: -0.1833, G Loss: -1.0240, W-dist: 0.2474, Time: 81.90s
# Epoch 242, D Loss: -0.2021, G Loss: -1.1132, W-dist: 0.2713, Time: 59.06s
# Epoch 243, D Loss: -0.2032, G Loss: -1.2490, W-dist: 0.2833, Time: 57.42s
# Epoch 244, D Loss: -0.2639, G Loss: -1.3519, W-dist: 0.3328, Time: 56.92s
# Epoch 245, D Loss: -0.3057, G Loss: -1.4454, W-dist: 0.3661, Time: 81.90s
# Epoch 246, D Loss: -0.2831, G Loss: -1.5581, W-dist: 0.3458, Time: 81.90s
# Epoch 247, D Loss: -0.3013, G Loss: -1.6668, W-dist: 0.3564, Time: 81.90s
# Epoch 248, D Loss: -0.3250, G Loss: -1.7615, W-dist: 0.3647, Time: 59.13s
# Epoch 249, D Loss: -0.2911, G Loss: -1.8689, W-dist: 0.3349, Time: 56.69s
# Epoch 250, D Loss: -0.2595, G Loss: -1.9625, W-dist: 0.2988, Time: 57.11s
# Epoch 251, D Loss: -0.2219, G Loss: -2.0012, W-dist: 0.2571, Time: 57.68s
# Epoch 252, D Loss: -0.2300, G Loss: -2.0441, W-dist: 0.2613, Time: 56.98s
# Epoch 253, D Loss: -0.1659, G Loss: -2.0565, W-dist: 0.1984, Time: 56.67s
# Epoch 254, D Loss: -0.1569, G Loss: -2.0367, W-dist: 0.1935, Time: 57.24s
# Epoch 255, D Loss: -0.1379, G Loss: -1.9940, W-dist: 0.1723, Time: 58.92s
# Epoch 256, D Loss: -0.1320, G Loss: -1.9580, W-dist: 0.1697, Time: 56.86s
# Epoch 257, D Loss: -0.1343, G Loss: -1.8526, W-dist: 0.1733, Time: 56.48s
# Epoch 258, D Loss: -0.1242, G Loss: -1.8022, W-dist: 0.1733, Time: 56.84s
# Epoch 259, D Loss: -0.1380, G Loss: -1.7368, W-dist: 0.1873, Time: 58.54s
# Epoch 260, D Loss: -0.1452, G Loss: -1.6520, W-dist: 0.2002, Time: 56.97s
# Epoch 261, D Loss: -0.1666, G Loss: -1.5866, W-dist: 0.2186, Time: 81.91s
# Epoch 262, D Loss: -0.1666, G Loss: -1.5623, W-dist: 0.2238, Time: 59.22s
# Epoch 263, D Loss: -0.1606, G Loss: -1.5280, W-dist: 0.2133, Time: 57.87s
# Epoch 264, D Loss: -0.2165, G Loss: -1.5279, W-dist: 0.2696, Time: 57.93s
# Epoch 265, D Loss: -0.2067, G Loss: -1.5472, W-dist: 0.2693, Time: 57.17s
# Epoch 266, D Loss: -0.1946, G Loss: -1.6121, W-dist: 0.2535, Time: 81.90s
# Epoch 267, D Loss: -0.2319, G Loss: -1.6478, W-dist: 0.2748, Time: 57.40s
# Epoch 268, D Loss: -0.2285, G Loss: -1.6890, W-dist: 0.2760, Time: 57.26s
# Epoch 269, D Loss: -0.2312, G Loss: -1.7866, W-dist: 0.2761, Time: 58.44s
# Epoch 270, D Loss: -0.2335, G Loss: -1.8806, W-dist: 0.2715, Time: 56.65s
# Epoch 271, D Loss: -0.2543, G Loss: -1.9924, W-dist: 0.2939, Time: 81.90s
# Epoch 272, D Loss: -0.2585, G Loss: -2.0704, W-dist: 0.2940, Time: 56.76s
# Epoch 273, D Loss: -0.2476, G Loss: -2.1045, W-dist: 0.2775, Time: 58.86s
# Epoch 274, D Loss: -0.2236, G Loss: -2.1902, W-dist: 0.2522, Time: 56.74s
# Epoch 275, D Loss: -0.2142, G Loss: -2.2709, W-dist: 0.2448, Time: 56.92s
# Epoch 276, D Loss: -0.1957, G Loss: -2.2986, W-dist: 0.2332, Time: 58.48s
# Epoch 277, D Loss: -0.1861, G Loss: -2.3694, W-dist: 0.2128, Time: 56.65s
# Epoch 278, D Loss: -0.1696, G Loss: -2.3420, W-dist: 0.2010, Time: 56.97s
# Epoch 279, D Loss: -0.1490, G Loss: -2.3150, W-dist: 0.1857, Time: 57.24s
# Epoch 280, D Loss: -0.1584, G Loss: -2.2391, W-dist: 0.1933, Time: 58.89s
# Epoch 281, D Loss: -0.1495, G Loss: -2.1997, W-dist: 0.1866, Time: 57.11s
# Epoch 282, D Loss: -0.1770, G Loss: -2.1523, W-dist: 0.2167, Time: 56.78s
# Epoch 283, D Loss: -0.1971, G Loss: -2.0260, W-dist: 0.2341, Time: 57.26s
# Epoch 284, D Loss: -0.2101, G Loss: -1.9162, W-dist: 0.2515, Time: 58.91s
# Epoch 285, D Loss: -0.2110, G Loss: -1.8906, W-dist: 0.2576, Time: 56.91s
# Epoch 286, D Loss: -0.2210, G Loss: -1.8745, W-dist: 0.2636, Time: 57.20s
# Epoch 287, D Loss: -0.2341, G Loss: -1.7913, W-dist: 0.2731, Time: 56.85s
# Epoch 288, D Loss: -0.2304, G Loss: -1.8096, W-dist: 0.2653, Time: 57.99s
# Epoch 289, D Loss: -0.2239, G Loss: -1.8222, W-dist: 0.2618, Time: 81.91s
# Epoch 290, D Loss: -0.2398, G Loss: -1.8638, W-dist: 0.2716, Time: 58.11s
# Epoch 291, D Loss: -0.2433, G Loss: -1.8883, W-dist: 0.2715, Time: 58.05s
# Epoch 292, D Loss: -0.2145, G Loss: -1.9395, W-dist: 0.2432, Time: 81.91s
# Epoch 293, D Loss: -0.2083, G Loss: -1.9908, W-dist: 0.2404, Time: 81.90s
# Epoch 294, D Loss: -0.2158, G Loss: -2.0057, W-dist: 0.2465, Time: 81.90s
# Epoch 295, D Loss: -0.2003, G Loss: -2.0667, W-dist: 0.2291, Time: 57.98s
# Epoch 296, D Loss: -0.1798, G Loss: -2.0862, W-dist: 0.2100, Time: 81.90s
# Epoch 297, D Loss: -0.2039, G Loss: -2.1072, W-dist: 0.2345, Time: 81.90s
# Epoch 298, D Loss: -0.1907, G Loss: -2.1347, W-dist: 0.2209, Time: 81.90s
# Epoch 299, D Loss: -0.1876, G Loss: -2.1188, W-dist: 0.2230, Time: 57.45s
# Epoch 300, D Loss: -0.1922, G Loss: -2.0822, W-dist: 0.2203, Time: 81.90s
# Epoch 301, D Loss: -0.2065, G Loss: -2.0466, W-dist: 0.2360, Time: 57.60s
# Epoch 302, D Loss: -0.1988, G Loss: -2.0826, W-dist: 0.2297, Time: 58.64s
# Epoch 303, D Loss: -0.2037, G Loss: -2.0637, W-dist: 0.2383, Time: 57.98s
# Epoch 304, D Loss: -0.2076, G Loss: -1.9921, W-dist: 0.2431, Time: 59.10s
# Epoch 305, D Loss: -0.2037, G Loss: -1.9714, W-dist: 0.2352, Time: 57.66s
# Epoch 306, D Loss: -0.2288, G Loss: -1.9647, W-dist: 0.2606, Time: 56.61s
# Epoch 307, D Loss: -0.2144, G Loss: -1.9301, W-dist: 0.2457, Time: 81.90s
# Epoch 308, D Loss: -0.2264, G Loss: -1.9313, W-dist: 0.2621, Time: 58.83s
# Epoch 309, D Loss: -0.2031, G Loss: -1.9361, W-dist: 0.2387, Time: 57.72s
# Epoch 310, D Loss: -0.2115, G Loss: -1.9497, W-dist: 0.2430, Time: 57.42s
# Epoch 311, D Loss: -0.1933, G Loss: -1.9942, W-dist: 0.2257, Time: 56.75s
# Epoch 312, D Loss: -0.2038, G Loss: -2.0506, W-dist: 0.2352, Time: 81.90s
# Epoch 313, D Loss: -0.1934, G Loss: -2.0366, W-dist: 0.2278, Time: 57.21s
# Epoch 314, D Loss: -0.1873, G Loss: -2.0427, W-dist: 0.2259, Time: 57.16s
# Epoch 315, D Loss: -0.1791, G Loss: -2.0745, W-dist: 0.2152, Time: 58.85s
# Epoch 316, D Loss: -0.1754, G Loss: -2.0189, W-dist: 0.2112, Time: 81.90s
# Epoch 317, D Loss: -0.2026, G Loss: -1.9837, W-dist: 0.2350, Time: 81.90s
# Epoch 318, D Loss: -0.2113, G Loss: -1.9520, W-dist: 0.2432, Time: 60.33s
# Epoch 319, D Loss: -0.2075, G Loss: -1.8578, W-dist: 0.2415, Time: 57.96s
# Epoch 320, D Loss: -0.2081, G Loss: -1.8228, W-dist: 0.2449, Time: 57.91s
# Epoch 321, D Loss: -0.1981, G Loss: -1.8269, W-dist: 0.2306, Time: 57.54s
# Epoch 322, D Loss: -0.2093, G Loss: -1.7689, W-dist: 0.2417, Time: 58.24s
# Epoch 323, D Loss: -0.1842, G Loss: -1.7585, W-dist: 0.2172, Time: 57.02s
# Epoch 324, D Loss: -0.1793, G Loss: -1.7425, W-dist: 0.2111, Time: 57.39s
# Epoch 325, D Loss: -0.2069, G Loss: -1.7118, W-dist: 0.2361, Time: 57.00s
# Epoch 326, D Loss: -0.1807, G Loss: -1.7335, W-dist: 0.2140, Time: 58.47s
# Epoch 327, D Loss: -0.1968, G Loss: -1.6934, W-dist: 0.2266, Time: 57.42s
# Epoch 328, D Loss: -0.1883, G Loss: -1.6886, W-dist: 0.2193, Time: 57.57s
# Epoch 329, D Loss: -0.1763, G Loss: -1.6622, W-dist: 0.2141, Time: 57.72s
# Epoch 330, D Loss: -0.2051, G Loss: -1.6628, W-dist: 0.2363, Time: 59.16s
# Epoch 331, D Loss: -0.1859, G Loss: -1.6721, W-dist: 0.2189, Time: 56.95s
# Epoch 332, D Loss: -0.2005, G Loss: -1.6699, W-dist: 0.2432, Time: 56.83s
# Epoch 333, D Loss: -0.2066, G Loss: -1.6802, W-dist: 0.2415, Time: 81.91s
# Epoch 334, D Loss: -0.2232, G Loss: -1.6845, W-dist: 0.2639, Time: 62.10s
# Epoch 335, D Loss: -0.2017, G Loss: -1.6871, W-dist: 0.2371, Time: 59.06s
# Epoch 336, D Loss: -0.2121, G Loss: -1.6762, W-dist: 0.2413, Time: 57.84s
# Epoch 337, D Loss: -0.1952, G Loss: -1.6943, W-dist: 0.2320, Time: 81.90s
# Epoch 338, D Loss: -0.2064, G Loss: -1.7006, W-dist: 0.2514, Time: 58.98s
# Epoch 339, D Loss: -0.2085, G Loss: -1.7331, W-dist: 0.2536, Time: 58.63s
# Epoch 340, D Loss: -0.1900, G Loss: -1.7186, W-dist: 0.2246, Time: 58.43s
# Epoch 341, D Loss: -0.2073, G Loss: -1.7127, W-dist: 0.2540, Time: 59.47s
# Epoch 342, D Loss: -0.1806, G Loss: -1.7145, W-dist: 0.2245, Time: 81.91s
# Epoch 343, D Loss: -0.1958, G Loss: -1.6993, W-dist: 0.2334, Time: 81.91s
# Epoch 344, D Loss: -0.1955, G Loss: -1.7016, W-dist: 0.2334, Time: 60.41s
# Epoch 345, D Loss: -0.2003, G Loss: -1.7326, W-dist: 0.2329, Time: 58.09s
# Epoch 346, D Loss: -0.2029, G Loss: -1.7058, W-dist: 0.2447, Time: 58.14s
# Epoch 347, D Loss: -0.2017, G Loss: -1.6742, W-dist: 0.2347, Time: 57.78s
# Epoch 348, D Loss: -0.1740, G Loss: -1.6311, W-dist: 0.2100, Time: 61.02s
# Epoch 349, D Loss: -0.1906, G Loss: -1.6301, W-dist: 0.2347, Time: 57.85s
# Epoch 350, D Loss: -0.1922, G Loss: -1.6541, W-dist: 0.2277, Time: 58.51s
# Epoch 351, D Loss: -0.1957, G Loss: -1.6727, W-dist: 0.2332, Time: 58.65s
# Epoch 352, D Loss: -0.1859, G Loss: -1.6603, W-dist: 0.2265, Time: 81.91s
# Epoch 353, D Loss: -0.1781, G Loss: -1.6620, W-dist: 0.2211, Time: 58.79s
# Epoch 354, D Loss: -0.2053, G Loss: -1.6767, W-dist: 0.2492, Time: 59.17s
# Epoch 355, D Loss: -0.1907, G Loss: -1.7119, W-dist: 0.2369, Time: 59.60s
# Epoch 356, D Loss: -0.1876, G Loss: -1.7519, W-dist: 0.2346, Time: 58.57s
# Epoch 357, D Loss: -0.1819, G Loss: -1.7254, W-dist: 0.2343, Time: 81.90s
# Epoch 358, D Loss: -0.2052, G Loss: -1.7181, W-dist: 0.2440, Time: 62.11s
# Epoch 359, D Loss: -0.1884, G Loss: -1.7053, W-dist: 0.2360, Time: 59.05s
# Epoch 360, D Loss: -0.1864, G Loss: -1.7125, W-dist: 0.2288, Time: 58.00s
# Epoch 361, D Loss: -0.1870, G Loss: -1.7462, W-dist: 0.2369, Time: 81.91s
# Epoch 362, D Loss: -0.1924, G Loss: -1.7217, W-dist: 0.2368, Time: 61.32s
# Epoch 363, D Loss: -0.1827, G Loss: -1.7138, W-dist: 0.2313, Time: 58.29s
# Epoch 364, D Loss: -0.1797, G Loss: -1.6816, W-dist: 0.2220, Time: 57.79s
# Epoch 365, D Loss: -0.1681, G Loss: -1.6893, W-dist: 0.2265, Time: 58.53s
# Epoch 366, D Loss: -0.1694, G Loss: -1.7112, W-dist: 0.2176, Time: 61.87s
# Epoch 367, D Loss: -0.1825, G Loss: -1.7723, W-dist: 0.2180, Time: 59.29s
# Epoch 368, D Loss: -0.1739, G Loss: -1.7482, W-dist: 0.2168, Time: 58.57s
# Epoch 369, D Loss: -0.1808, G Loss: -1.7754, W-dist: 0.2251, Time: 61.54s
# Epoch 370, D Loss: -0.1780, G Loss: -1.7446, W-dist: 0.2212, Time: 58.79s
# Epoch 371, D Loss: -0.1838, G Loss: -1.7544, W-dist: 0.2277, Time: 58.60s
# Epoch 372, D Loss: -0.1649, G Loss: -1.7701, W-dist: 0.2144, Time: 81.90s
# Epoch 373, D Loss: -0.1991, G Loss: -1.7634, W-dist: 0.2454, Time: 61.66s
# Epoch 374, D Loss: -0.1828, G Loss: -1.7211, W-dist: 0.2351, Time: 58.49s
# Epoch 375, D Loss: -0.2043, G Loss: -1.7201, W-dist: 0.2430, Time: 58.67s
# Epoch 376, D Loss: -0.1654, G Loss: -1.6741, W-dist: 0.2149, Time: 81.90s
# Epoch 377, D Loss: -0.1887, G Loss: -1.6884, W-dist: 0.2374, Time: 81.91s
# Epoch 378, D Loss: -0.1810, G Loss: -1.6736, W-dist: 0.2258, Time: 59.45s
# Epoch 379, D Loss: -0.1672, G Loss: -1.6866, W-dist: 0.2107, Time: 59.33s
# Epoch 380, D Loss: -0.1934, G Loss: -1.6625, W-dist: 0.2329, Time: 58.61s
# Epoch 381, D Loss: -0.1916, G Loss: -1.6489, W-dist: 0.2313, Time: 58.90s
# Epoch 382, D Loss: -0.1668, G Loss: -1.6525, W-dist: 0.2113, Time: 60.57s
# Epoch 383, D Loss: -0.1608, G Loss: -1.6439, W-dist: 0.2074, Time: 59.86s
# Epoch 384, D Loss: -0.1457, G Loss: -1.6307, W-dist: 0.1962, Time: 58.31s
# Epoch 385, D Loss: -0.1964, G Loss: -1.6349, W-dist: 0.2371, Time: 57.99s
# Epoch 386, D Loss: -0.1716, G Loss: -1.6448, W-dist: 0.2146, Time: 59.38s
# Epoch 387, D Loss: -0.1743, G Loss: -1.6487, W-dist: 0.2205, Time: 59.04s
# Epoch 388, D Loss: -0.1722, G Loss: -1.6506, W-dist: 0.2144, Time: 58.05s
# Epoch 389, D Loss: -0.1652, G Loss: -1.6464, W-dist: 0.1997, Time: 58.08s
# Epoch 390, D Loss: -0.1534, G Loss: -1.6579, W-dist: 0.1988, Time: 81.90s
# Epoch 391, D Loss: -0.1460, G Loss: -1.6482, W-dist: 0.1847, Time: 59.82s
# Epoch 392, D Loss: -0.1525, G Loss: -1.6906, W-dist: 0.1891, Time: 58.74s
# Epoch 393, D Loss: -0.1422, G Loss: -1.6660, W-dist: 0.1885, Time: 58.53s
# Epoch 394, D Loss: -0.1476, G Loss: -1.6879, W-dist: 0.1931, Time: 60.68s
# Epoch 395, D Loss: -0.1363, G Loss: -1.7038, W-dist: 0.1896, Time: 58.53s
# Epoch 396, D Loss: -0.1456, G Loss: -1.6992, W-dist: 0.1926, Time: 57.95s
# Epoch 397, D Loss: -0.1689, G Loss: -1.6944, W-dist: 0.2135, Time: 58.27s
# Epoch 398, D Loss: -0.1516, G Loss: -1.7140, W-dist: 0.1957, Time: 141.90s
# Epoch 399, D Loss: -0.1644, G Loss: -1.7236, W-dist: 0.2103, Time: 58.53s
# Epoch 400, D Loss: -0.1470, G Loss: -1.7372, W-dist: 0.2009, Time: 59.77s
# Epoch 401, D Loss: -0.1484, G Loss: -1.7463, W-dist: 0.2013, Time: 58.06s
# Epoch 402, D Loss: -0.1433, G Loss: -1.7427, W-dist: 0.1931, Time: 59.70s
# Epoch 403, D Loss: -0.1198, G Loss: -1.7735, W-dist: 0.1646, Time: 57.71s
# Epoch 404, D Loss: -0.1246, G Loss: -1.7785, W-dist: 0.1816, Time: 58.78s
# Epoch 405, D Loss: -0.1115, G Loss: -1.7984, W-dist: 0.1676, Time: 57.80s
# Epoch 406, D Loss: -0.1346, G Loss: -1.7658, W-dist: 0.1820, Time: 57.56s
# Epoch 407, D Loss: -0.1175, G Loss: -1.7336, W-dist: 0.1751, Time: 81.90s
# Epoch 408, D Loss: -0.1273, G Loss: -1.7162, W-dist: 0.1800, Time: 60.03s
# Epoch 409, D Loss: -0.1373, G Loss: -1.6798, W-dist: 0.1862, Time: 57.65s
# Epoch 410, D Loss: -0.1485, G Loss: -1.6812, W-dist: 0.1883, Time: 57.40s
# Epoch 411, D Loss: -0.1414, G Loss: -1.6577, W-dist: 0.1816, Time: 58.47s
# Epoch 412, D Loss: -0.1130, G Loss: -1.6633, W-dist: 0.1632, Time: 81.90s
# Epoch 413, D Loss: -0.1198, G Loss: -1.6689, W-dist: 0.1685, Time: 81.90s
# Epoch 414, D Loss: -0.0940, G Loss: -1.6827, W-dist: 0.1378, Time: 81.90s
# Epoch 415, D Loss: -0.0909, G Loss: -1.7032, W-dist: 0.1332, Time: 81.90s
# Epoch 416, D Loss: -0.0693, G Loss: -1.7172, W-dist: 0.1087, Time: 59.74s
# Epoch 417, D Loss: -0.0612, G Loss: -1.7403, W-dist: 0.1130, Time: 58.31s
# Epoch 418, D Loss: -0.0499, G Loss: -1.7548, W-dist: 0.1051, Time: 59.63s
# Epoch 419, D Loss: -0.0770, G Loss: -1.7481, W-dist: 0.1346, Time: 81.90s
# Epoch 420, D Loss: -0.1064, G Loss: -1.7596, W-dist: 0.1571, Time: 81.90s
# Epoch 421, D Loss: -0.1181, G Loss: -1.7529, W-dist: 0.1669, Time: 60.24s
# Epoch 422, D Loss: -0.1356, G Loss: -1.7651, W-dist: 0.1839, Time: 57.98s
# Epoch 423, D Loss: -0.1242, G Loss: -1.7915, W-dist: 0.1758, Time: 59.30s
# Epoch 424, D Loss: -0.1182, G Loss: -1.8021, W-dist: 0.1813, Time: 81.91s
# Epoch 425, D Loss: -0.1000, G Loss: -1.8751, W-dist: 0.1457, Time: 81.90s
# Epoch 426, D Loss: -0.0518, G Loss: -1.9307, W-dist: 0.1065, Time: 81.91s
# Epoch 427, D Loss: -0.0170, G Loss: -1.9679, W-dist: 0.0705, Time: 81.91s
# Epoch 428, D Loss: 0.0136, G Loss: -2.0246, W-dist: 0.0530, Time: 62.49s
# Epoch 429, D Loss: 0.0477, G Loss: -2.0616, W-dist: 0.0085, Time: 58.73s
# Epoch 430, D Loss: 0.0742, G Loss: -2.0962, W-dist: 0.0003, Time: 58.40s
# Epoch 431, D Loss: 0.0385, G Loss: -2.0432, W-dist: 0.0362, Time: 81.90s
# Epoch 432, D Loss: 0.0026, G Loss: -1.9549, W-dist: 0.0749, Time: 81.90s
# Epoch 433, D Loss: -0.1213, G Loss: -1.7584, W-dist: 0.1831, Time: 59.24s
# Epoch 434, D Loss: -0.2457, G Loss: -1.5446, W-dist: 0.3156, Time: 57.98s
# Epoch 435, D Loss: -0.3076, G Loss: -1.3579, W-dist: 0.3674, Time: 59.49s
# Epoch 436, D Loss: -0.3642, G Loss: -1.2691, W-dist: 0.4075, Time: 57.74s
# Epoch 437, D Loss: -0.3065, G Loss: -1.2722, W-dist: 0.3572, Time: 81.90s
# Epoch 438, D Loss: -0.2876, G Loss: -1.3341, W-dist: 0.3297, Time: 58.92s
# Epoch 439, D Loss: -0.2244, G Loss: -1.4367, W-dist: 0.2649, Time: 59.20s
# Epoch 440, D Loss: -0.1434, G Loss: -1.5270, W-dist: 0.1995, Time: 58.06s
# Epoch 441, D Loss: -0.0855, G Loss: -1.6252, W-dist: 0.1360, Time: 57.86s
# Epoch 442, D Loss: -0.0292, G Loss: -1.7248, W-dist: 0.0884, Time: 81.90s
# Epoch 443, D Loss: 0.0413, G Loss: -1.8111, W-dist: 0.0086, Time: 81.90s
# Epoch 444, D Loss: 0.0575, G Loss: -1.8736, W-dist: -0.0006, Time: 59.43s
# Epoch 445, D Loss: 0.0761, G Loss: -1.9132, W-dist: -0.0014, Time: 58.27s
# Epoch 446, D Loss: 0.0300, G Loss: -1.8783, W-dist: 0.0339, Time: 59.63s
# Epoch 447, D Loss: -0.0400, G Loss: -1.8461, W-dist: 0.0987, Time: 57.85s
# Epoch 448, D Loss: -0.1510, G Loss: -1.7968, W-dist: 0.2006, Time: 81.90s
# Epoch 449, D Loss: -0.2455, G Loss: -1.6973, W-dist: 0.2899, Time: 81.91s
# Epoch 450, D Loss: -0.3269, G Loss: -1.5904, W-dist: 0.3642, Time: 60.38s
# Epoch 451, D Loss: -0.3732, G Loss: -1.4513, W-dist: 0.4156, Time: 58.07s
# Epoch 452, D Loss: -0.3705, G Loss: -1.3492, W-dist: 0.4047, Time: 57.82s
# Epoch 453, D Loss: -0.3642, G Loss: -1.2237, W-dist: 0.4007, Time: 58.02s
# Epoch 454, D Loss: -0.3314, G Loss: -1.1696, W-dist: 0.3699, Time: 60.60s
# Epoch 455, D Loss: -0.2806, G Loss: -1.1467, W-dist: 0.3123, Time: 59.57s
# Epoch 456, D Loss: -0.2335, G Loss: -1.1629, W-dist: 0.2685, Time: 58.30s
# Epoch 457, D Loss: -0.1720, G Loss: -1.1567, W-dist: 0.2084, Time: 58.17s
# Epoch 458, D Loss: -0.1348, G Loss: -1.1762, W-dist: 0.1740, Time: 59.43s
# Epoch 459, D Loss: -0.0811, G Loss: -1.1845, W-dist: 0.1221, Time: 81.90s
# Epoch 460, D Loss: -0.0327, G Loss: -1.2216, W-dist: 0.0758, Time: 59.81s
# Epoch 461, D Loss: -0.0450, G Loss: -1.2121, W-dist: 0.0934, Time: 58.17s
# Epoch 462, D Loss: -0.0549, G Loss: -1.2000, W-dist: 0.1043, Time: 59.49s
# Epoch 463, D Loss: -0.1203, G Loss: -1.1714, W-dist: 0.1735, Time: 57.51s
# Epoch 464, D Loss: -0.1949, G Loss: -1.1423, W-dist: 0.2441, Time: 81.90s
# Epoch 465, D Loss: -0.2501, G Loss: -1.1316, W-dist: 0.2989, Time: 81.90s
# Epoch 466, D Loss: -0.2935, G Loss: -1.1074, W-dist: 0.3422, Time: 60.54s
# Epoch 467, D Loss: -0.3130, G Loss: -1.1668, W-dist: 0.3534, Time: 58.59s
# Epoch 468, D Loss: -0.2953, G Loss: -1.1843, W-dist: 0.3399, Time: 58.09s
# Epoch 469, D Loss: -0.2709, G Loss: -1.2057, W-dist: 0.3119, Time: 81.90s
# Epoch 470, D Loss: -0.2319, G Loss: -1.2348, W-dist: 0.2711, Time: 60.46s
# Epoch 471, D Loss: -0.1873, G Loss: -1.2547, W-dist: 0.2228, Time: 57.99s
# Epoch 472, D Loss: -0.1435, G Loss: -1.2634, W-dist: 0.1809, Time: 57.64s
# Epoch 473, D Loss: -0.1130, G Loss: -1.2785, W-dist: 0.1544, Time: 58.37s
# Epoch 474, D Loss: -0.0807, G Loss: -1.2940, W-dist: 0.1263, Time: 81.90s
# Epoch 475, D Loss: -0.0615, G Loss: -1.2996, W-dist: 0.1104, Time: 81.90s
# Epoch 476, D Loss: -0.0465, G Loss: -1.2925, W-dist: 0.0974, Time: 81.90s
# Epoch 477, D Loss: -0.0631, G Loss: -1.2741, W-dist: 0.1117, Time: 60.58s
# Epoch 478, D Loss: -0.1005, G Loss: -1.2495, W-dist: 0.1427, Time: 81.90s
# Epoch 479, D Loss: -0.1628, G Loss: -1.2159, W-dist: 0.2086, Time: 60.19s
# Epoch 480, D Loss: -0.1959, G Loss: -1.1768, W-dist: 0.2425, Time: 81.91s
# Epoch 481, D Loss: -0.2323, G Loss: -1.1446, W-dist: 0.2833, Time: 61.02s
# Epoch 482, D Loss: -0.2319, G Loss: -1.1197, W-dist: 0.2896, Time: 58.35s
# Epoch 483, D Loss: -0.2348, G Loss: -1.1335, W-dist: 0.2861, Time: 57.93s
# Epoch 484, D Loss: -0.1947, G Loss: -1.1204, W-dist: 0.2462, Time: 57.97s
# Epoch 485, D Loss: -0.1448, G Loss: -1.1013, W-dist: 0.1968, Time: 81.90s
# Epoch 486, D Loss: -0.1075, G Loss: -1.1067, W-dist: 0.1579, Time: 81.91s
# Epoch 487, D Loss: -0.0513, G Loss: -1.0967, W-dist: 0.1009, Time: 59.95s
# Epoch 488, D Loss: 0.0051, G Loss: -1.1090, W-dist: 0.0480, Time: 58.60s
# Epoch 489, D Loss: 0.0600, G Loss: -1.1048, W-dist: 0.0041, Time: 60.12s
# Epoch 490, D Loss: 0.0811, G Loss: -1.1129, W-dist: -0.0142, Time: 81.90s
# Epoch 491, D Loss: 0.0981, G Loss: -1.1336, W-dist: -0.0221, Time: 59.03s
# Epoch 492, D Loss: 0.0740, G Loss: -1.1482, W-dist: 0.0011, Time: 58.66s
# Epoch 493, D Loss: -0.0082, G Loss: -1.1789, W-dist: 0.0767, Time: 59.96s
# Epoch 494, D Loss: -0.2083, G Loss: -1.1361, W-dist: 0.2766, Time: 58.21s
# Epoch 495, D Loss: -0.4453, G Loss: -1.1177, W-dist: 0.5063, Time: 81.90s
# Epoch 496, D Loss: -0.5672, G Loss: -1.1462, W-dist: 0.6217, Time: 81.90s
# Epoch 497, D Loss: -0.5451, G Loss: -1.1913, W-dist: 0.5942, Time: 60.23s
# Epoch 498, D Loss: -0.4713, G Loss: -1.3075, W-dist: 0.5151, Time: 58.44s
# Epoch 499, D Loss: -0.3871, G Loss: -1.3965, W-dist: 0.4315, Time: 58.70s
# Epoch 500, D Loss: -0.2908, G Loss: -1.4727, W-dist: 0.3319, Time: 81.90s
# Training finished.

# %%
import matplotlib.pyplot as plt

def plot_loss_curves(d_losses, g_losses, w_distances):
    """
    Visualizes the loss curves of the Discriminator, Generator, and Wasserstein Distance.

    Parameters:
    - d_loss_hist: List of discriminator loss values
    - g_loss_hist: List of generator loss values
    - wasserstein_hist: List of Wasserstein distance values
    """
    plt.figure(figsize=(12, 5))

    # Subplot 1: Discriminator and Generator Losses
    plt.subplot(1, 2, 1)
    plt.plot(d_loss_hist, label='Discriminator Loss', color='r')
    plt.plot(g_loss_hist, label='Generator Loss', color='b')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Discriminator and Generator Losses')
    plt.legend()
    plt.grid(True)

    # Subplot 2: Wasserstein Distance
    plt.subplot(1, 2, 2)
    plt.plot(wasserstein_hist, label='Wasserstein Distance', color='purple')
    plt.xlabel('Epoch')
    plt.ylabel('W-Distance')
    plt.title('Wasserstein Distance Over Time')
    plt.legend()
    plt.grid(True)

    # Tight layout for better spacing
    plt.tight_layout()
    plt.show()

# %%
# Plot the loss curves
plot_loss_curves(d_loss_hist, g_loss_hist, wasserstein_hist)

# %%
def generate_synthetic_data(generator, num_samples):
    """
    Generate synthetic data using the trained generator.

    Args:
        generator: Trained generator model.
        num_samples: Number of synthetic sequences to generate.

    Returns:
        synthetic_data: Numpy array of shape (num_samples, SEQ_LEN, FEATURE_DIM)
    """
    noise = tf.random.normal([num_samples, SEQ_LEN, LATENT_DIM])
    synthetic_data = generator(noise, training=False).numpy()
    return synthetic_data

# %%
num_samples = 1000
synthetic_samples = generate_synthetic_data(generator, num_samples)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-968875625f48> in <cell line: 0>()
#       1 num_samples = 1000
# ----> 2 synthetic_samples = generate_synthetic_data(generator, num_samples)
#
# NameError: name 'generate_synthetic_data' is not defined

# %%
synthetic_samples
# Out:
# array([[[ 0.7132526 ,  0.8689619 ,  0.9495229 ],
#         [ 0.41276857,  0.6145607 ,  0.57228774],
#         [ 0.1184944 ,  0.30902788,  0.16050668],
#         ...,
#         [ 0.36697385,  0.53768706,  0.43712646],
#         [ 0.89003235,  0.8187122 ,  0.8411457 ],
#         [ 0.8687464 ,  0.87123847,  0.8234146 ]],
#
#        [[ 0.2565246 ,  0.2317809 ,  0.24129139],
#         [ 0.3770718 ,  0.33430776,  0.39356202],
#         [ 0.29524356,  0.3330904 ,  0.33046734],
#         ...,
#         [ 0.2199013 ,  0.31568012,  0.1528458 ],
#         [ 0.2318562 ,  0.4125757 ,  0.1603308 ],
#         [ 0.3824717 ,  0.40275213,  0.27407905]],
#
#        [[ 0.5176575 ,  0.5587179 ,  0.5855014 ],
#         [ 0.6836002 ,  0.67715764,  0.6773952 ],
#         [ 0.6285051 ,  0.60589087,  0.5008968 ],
#         ...,
#         [ 0.98128647,  0.89817643,  0.6842907 ],
#         [ 0.6489802 ,  0.67410785,  0.33692098],
#         [ 0.55273354,  0.45603466,  0.1337142 ]],
#
#        ...,
#
#        [[ 0.29345235,  0.28493112,  0.3465278 ],
#         [ 0.39528236,  0.33610758,  0.4030075 ],
#         [ 0.45693004,  0.33983865,  0.28743076],
#         ...,
#         [ 0.496148  ,  0.52992964,  0.33300322],
#         [ 0.4619136 ,  0.49527043,  0.33797073],
#         [ 0.82814294,  0.78085345,  0.6876465 ]],
#
#        [[ 0.48075888,  0.60885   ,  0.64120513],
#         [ 0.2857793 ,  0.4754263 ,  0.47139502],
#         [ 0.13471669,  0.27623716,  0.25758278],
#         ...,
#         [ 0.08564266,  0.07595626, -0.03857476],
#         [ 0.22809619,  0.16776821,  0.01106905],
#         [ 0.2686437 ,  0.13875893, -0.06717939]],
#
#        [[ 0.14605668,  0.17103642,  0.14474592],
#         [-0.01481079,  0.03639966, -0.00832963],
#         [ 0.37773287,  0.2904711 ,  0.18666653],
#         ...,
#         [ 0.6977711 ,  0.5453298 ,  0.3098911 ],
#         [ 0.57700825,  0.616682  ,  0.3272726 ],
#         [ 0.43075398,  0.40145072,  0.01068282]]], dtype=float32)

# %% [markdown]
# - Input: a noise sequence of shape (window_length, latent_dim). In practice, we often set window_length=60 (as in prior work) and latent_dim=1.
# - Recurrent layers: Two stacked GRU layers (return_sequences=True) process the input sequence.
# - Dense layers: After the RNN, we apply a TimeDistributed Dense with GELU activation to introduce nonlinearity and speed up convergence
#
# - A final TimeDistributed Dense (no activation) maps to the output features.
# - Output: a synthetic sequence of shape (window_length, output_dim) (e.g. (60,1)), matching the real data shape

# %%
import pandas as pd

# flatten sequence into tabular form
generated_data_flat = synthetic_samples.reshape(-1, len(features))
df_fake = pd.DataFrame(generated_data_flat, columns=features)
# Save to CSV
df_fake.to_csv('RGANdata.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0759a69e75ad> in <cell line: 0>()
#       2
#       3 # flatten sequence into tabular form
# ----> 4 generated_data_flat = synthetic_samples.reshape(-1, len(features))
#       5 df_fake = pd.DataFrame(generated_data_flat, columns=features)
#       6 # Save to CSV
#
# NameError: name 'synthetic_samples' is not defined

# %%
df_fake
# Out:
#          Value  Value_HeatPump  Value_OtherAppliances
# 0     0.713253        0.868962               0.949523
# 1     0.412769        0.614561               0.572288
# 2     0.118494        0.309028               0.160507
# 3     0.407504        0.564682               0.462939
# 4     0.366974        0.537687               0.437126
# ...        ...             ...                    ...
# 6995  0.377733        0.290471               0.186667
# 6996  0.408248        0.330673               0.143711
# 6997  0.697771        0.545330               0.309891
# 6998  0.577008        0.616682               0.327273
# 6999  0.430754        0.401451               0.010683
#
# [7000 rows x 3 columns]

# %%
# statistical overlap
def evaluate_statistics(sequence_data,synthetic):
    real_flat = sequence_data.reshape(-1, sequence_data.shape[-1])
    fake_flat = synthetic.reshape(-1, synthetic.shape[-1])

    stats = {}
    for i, feature_name in enumerate(features):
        real_mean = np.mean(real_flat[:, i])
        fake_mean = np.mean(fake_flat[:, i])
        real_std = np.std(real_flat[:, i])
        fake_std = np.std(fake_flat[:, i])

        stats[feature_name] = {
            "real_mean": real_mean,
            "fake_mean": fake_mean,
            "real_std": real_std,
            "fake_std": fake_std
        }
    return stats

# %%
# Evaluate
stats = evaluate_statistics(real_sequences, synthetic_samples)
for feat, s in stats.items():
    print(f"{feat}: Real μ={s['real_mean']:.3f}, Fake μ={s['fake_mean']:.3f} | Real σ={s['real_std']:.3f}, Fake σ={s['fake_std']:.3f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8a81931a6274> in <cell line: 0>()
#       1 # Evaluate
# ----> 2 stats = evaluate_statistics(real_sequences, synthetic_samples)
#       3 for feat, s in stats.items():
#       4     print(f"{feat}: Real μ={s['real_mean']:.3f}, Fake μ={s['fake_mean']:.3f} | Real σ={s['real_std']:.3f}, Fake σ={s['fake_std']:.3f}")
#
# NameError: name 'evaluate_statistics' is not defined

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'stats' is the output dictionary from evaluate_statistics()
features = list(stats.keys())
real_means = [stats[f]['real_mean'] for f in features]
fake_means = [stats[f]['fake_mean'] for f in features]
real_stds = [stats[f]['real_std'] for f in features]
fake_stds = [stats[f]['fake_std'] for f in features]

x = np.arange(len(features))  # label locations
width = 0.35  # width of the bars

fig, axs = plt.subplots(1, 2, figsize=(14, 5))

# Plot means
axs[0].bar(x - width/2, real_means, width, label='Real', color='skyblue')
axs[0].bar(x + width/2, fake_means, width, label='Synthetic', color='salmon')
axs[0].set_ylabel('Mean')
axs[0].set_title('Mean Comparison per Feature')
axs[0].set_xticks(x)
axs[0].set_xticklabels(features, rotation=45)
axs[0].legend()

# Plot stds
axs[1].bar(x - width/2, real_stds, width, label='Real', color='skyblue')
axs[1].bar(x + width/2, fake_stds, width, label='Synthetic', color='salmon')
axs[1].set_ylabel('Standard Deviation')
axs[1].set_title('Standard Deviation Comparison per Feature')
axs[1].set_xticks(x)
axs[1].set_xticklabels(features, rotation=45)
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Example variable shapes:
# sequence_data: shape (n_samples, seq_len, n_features)
# synthetic: shape (n_samples, seq_len, n_features)

# Assume feature names are in correct order from `stats.keys()`
feature_names = list(stats.keys())

# Reshape from (samples, time, features) to (samples * time, features)
real_reshaped = real_sequences.reshape(-1, real_sequences.shape[2])
synthetic_reshaped = synthetic_samples.reshape(-1, synthetic_samples.shape[2])

# Create DataFrames
real_df = pd.DataFrame(real_reshaped, columns=feature_names)
real_df["Source"] = "Real"

synthetic_df = pd.DataFrame(synthetic_reshaped, columns=feature_names)
synthetic_df["Source"] = "Synthetic"

# Combine for plotting
combined_df = pd.concat([real_df, synthetic_df], axis=0)

# Plot distributions
num_features = len(feature_names)
cols = 3
rows = (num_features + cols - 1) // cols

plt.figure(figsize=(5 * cols, 4 * rows))

for i, feature in enumerate(feature_names):
    plt.subplot(rows, cols, i + 1)
    sns.kdeplot(data=combined_df, x=feature, hue="Source", fill=True, common_norm=False, alpha=0.5)
    plt.title(f"Distribution of {feature}")
    plt.xlabel(feature)
    plt.ylabel("Density")

plt.tight_layout()
plt.show()

# %%
import numpy as np
from scipy.stats import entropy, wasserstein_distance


# === Metric Functions ===
def kl_divergence(p, q):
    p += 1e-8
    q += 1e-8
    return entropy(p, q)

def js_divergence(p, q):
    p += 1e-8
    q += 1e-8
    m = 0.5 * (p + q)
    return 0.5 * (entropy(p, m) + entropy(q, m))

# === Evaluation Function ===
def evaluate_gan_outputs(real_sequences, generated_sequences, feature_names=None):
    if isinstance(real_sequences, tf.Tensor):
        real_sequences = real_sequences.numpy()
    if isinstance(generated_sequences, tf.Tensor):
        generated_sequences = synthetic_samples.numpy()

    real_flat = real_sequences.reshape(-1, real_sequences.shape[-1])
    gen_flat = synthetic_samples.reshape(-1, synthetic_samples.shape[-1])
    n_features = real_flat.shape[-1]

    print("\n📊 RGAN Evaluation Metrics")
    for i in range(n_features):
        real_vals = real_flat[:, i]
        gen_vals = gen_flat[:, i]

        # Histogram for divergence metrics
        # Use density=True for normalized histograms suitable for divergence measures
        bins = np.histogram_bin_edges(np.concatenate([real_vals, gen_vals]), bins="auto")
        real_hist, _ = np.histogram(real_vals, bins=bins, density=True)
        gen_hist, _ = np.histogram(gen_vals, bins=bins, density=True)

        # Although density=True normalizes, explicitly re-normalizing
        # helps handle potential floating point issues and ensures sum is exactly 1.
        real_hist /= (np.sum(real_hist) + 1e-8) # Add small epsilon to avoid division by zero
        gen_hist /= (np.sum(gen_hist) + 1e-8)   # Add small epsilon

        # Metrics
        kl = kl_divergence(real_hist, gen_hist)
        js = js_divergence(real_hist, gen_hist)
        wd = wasserstein_distance(real_vals, gen_vals)

        fname = feature_names[i] if feature_names else f"Feature {i+1}"
        print(f"\n🔹 {fname}")
        print(f"  - KL Divergence        : {kl:.4f}")
        print(f"  - JS Divergence        : {js:.4f}")
        print(f"  - Wasserstein Distance : {wd:.4f}")
        # Removed MSE and MAE output

# %%
evaluate_gan_outputs(
    real_sequences=real_sequences,
    generated_sequences=synthetic_samples,  # Changed 'synthetic_samples' to 'generated_sequences'
    feature_names=["Value", "Value_HeatPump", "Value_OtherAppliances"]
)
# Out:
# 📊 RGAN Evaluation Metrics
#
# 🔹 Value
#   - KL Divergence        : 0.2942
#   - JS Divergence        : 0.0667
#   - Wasserstein Distance : 0.0507
#
# 🔹 Value_HeatPump
#   - KL Divergence        : 0.3862
#   - JS Divergence        : 0.0858
#   - Wasserstein Distance : 0.0500
#
# 🔹 Value_OtherAppliances
#   - KL Divergence        : 0.3614
#   - JS Divergence        : 0.1053
#   - Wasserstein Distance : 0.0795
