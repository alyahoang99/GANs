# %% [markdown]
# <a href="https://colab.research.google.com/github/alyahoang99/GANs/blob/main/RGAN1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import time
from tensorflow.keras import layers, models

# %%
FEATURE_DIM = 3
LATENT_DIM = 100
GRU_UNITS = 128
BATCH_SIZE = 100
EPOCHS = 600
GEN_LR = 2e-5
DISC_LR = 1e-5
BETA_1 = 0.5
DISC_UPDATES_PER_GEN = 6
LAMBDA_GP = 10.0
SEQ_LEN = 7  # Sequence length for the time steps

# %%
# =================== Data Preprocessing ===================
# data preprocess
# Load dataset
# Load smart meter data (Timestamp, Value, Value_HeatPump, Value_OtherAppliances)
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/GANs/resampleddata (1).csv', parse_dates=['Timestamp'])
df.set_index('Timestamp', inplace=True)

# Select relevant features
features = ['Value', 'Value_HeatPump', 'Value_OtherAppliances']
data = df[features].values.astype(np.float32)

# Normalize data to [0, 1] for tanh
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data)

def create_sequences(data, seq_len, batchsize):
    sequences = []
    for i in range(len(data) - seq_len + 1):
        seq = data[i:i + seq_len]
        if len(seq) == seq_len:
            sequences.append(seq)
    return np.array(sequences)

real_sequences = create_sequences(data, SEQ_LEN, BATCH_SIZE)
print("Sequence data shape:", real_sequences.shape)  # (num_samples, 7, 3)
# Out:
# Sequence data shape: (1011, 7, 3)

# %%
BUFFER_SIZE = 1000  # Optional, for shuffling

dataset = tf.data.Dataset.from_tensor_slices(real_sequences)
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE, drop_remainder=True)

# %%
dataset
# Out:
# <_BatchDataset element_spec=TensorSpec(shape=(100, 7, 3), dtype=tf.float32, name=None)>

# %%
from tensorflow.keras import layers

def attention_block(inputs):
    # Score computation
    scores = layers.Dense(inputs.shape[-1], activation='tanh')(inputs)
    weights = layers.Softmax(axis=1)(scores)

    # Context vector as weighted sum
    context = layers.Multiply()([weights, inputs])
    context = layers.Lambda(lambda x: tf.reduce_sum(x, axis=1))(context)
    return context

# %%
# =================== Generator ===================
def build_generator():
    z = layers.Input(shape=(SEQ_LEN, LATENT_DIM))
    x = layers.GRU(GRU_UNITS, return_sequences=True)(z)
    x = layers.GRU(GRU_UNITS, return_sequences=True)(x)
    x = layers.TimeDistributed(layers.Dense(GRU_UNITS, activation='gelu'))(x)
    x = layers.TimeDistributed(layers.Dense(FEATURE_DIM))(x)
    return models.Model(z, x, name="Generator")

# =================== Discriminator ===================
def build_discriminator():
    x_in = layers.Input(shape=(SEQ_LEN, FEATURE_DIM))
    x = layers.LSTM(GRU_UNITS, return_sequences=True)(x_in)
    x = attention_block(x)
    x = layers.Dense(GRU_UNITS, activation='tanh')(x)
    out = layers.Dense(1)(x)  # Linear output for WGAN
    return models.Model(x_in, out, name="Discriminator")

# %%
# =================== Gradient Penalty ===================
def gradient_penalty(discriminator, real, fake):
    alpha = tf.random.uniform([real.shape[0], 1, 1], 0., 1.)
    interpolated = alpha * real + (1 - alpha) * fake
    with tf.GradientTape() as tape:
        tape.watch(interpolated)
        pred = discriminator(interpolated)
    grads = tape.gradient(pred, interpolated)
    norm = tf.sqrt(tf.reduce_sum(tf.square(grads), axis=[1, 2]) + 1e-12)
    return tf.reduce_mean((norm - 1.0) ** 2)

# %%
# =================== Training Step ===================
def train_step(generator, discriminator, real_batch, gen_opt, disc_opt):
    batch_size = tf.shape(real_batch)[0]
    for _ in range(DISC_UPDATES_PER_GEN):
        noise = tf.random.normal([batch_size, SEQ_LEN, LATENT_DIM])
        with tf.GradientTape() as tape:
            fake = generator(noise)
            d_real = discriminator(real_batch)
            d_fake = discriminator(fake)
            gp = gradient_penalty(discriminator, real_batch, fake)
            wasserstein_distance = tf.reduce_mean(d_real) - tf.reduce_mean(d_fake)
            d_loss = tf.reduce_mean(d_fake) - tf.reduce_mean(d_real) + LAMBDA_GP * gp
        grads = tape.gradient(d_loss, discriminator.trainable_variables)
        disc_opt.apply_gradients(zip(grads, discriminator.trainable_variables))

    noise = tf.random.normal([batch_size, SEQ_LEN, LATENT_DIM])
    with tf.GradientTape() as tape:
        fake = generator(noise)
        d_fake = discriminator(fake)
        g_loss = -tf.reduce_mean(d_fake)
    grads = tape.gradient(g_loss, generator.trainable_variables)
    gen_opt.apply_gradients(zip(grads, generator.trainable_variables))

    return d_loss, g_loss, wasserstein_distance

# %%
generator = build_generator()
discriminator = build_discriminator()
gen_opt = tf.keras.optimizers.Adam(GEN_LR, beta_1=BETA_1)
disc_opt = tf.keras.optimizers.Adam(DISC_LR, beta_1=BETA_1)

# %%
# =================== Training Loop ===================
def train(dataset, epochs):
    d_loss_hist, g_loss_hist, wasserstein_hist = [], [], []

    for epoch in range(epochs):
        start = time.time()
        d_losses, g_losses, w_distances = [], [], []

        for real_batch in dataset:

            d_loss, g_loss, w_distance = train_step(generator, discriminator, real_batch, gen_opt, disc_opt)
            d_losses.append(d_loss.numpy())
            g_losses.append(g_loss.numpy())
            w_distances.append(w_distance.numpy())

        d_loss_mean = np.mean(d_losses)
        g_loss_mean = np.mean(g_losses)
        w_distance_mean = np.mean(w_distances)
        d_loss_hist.append(d_loss_mean)
        g_loss_hist.append(g_loss_mean)
        wasserstein_hist.append(w_distance_mean)

        print(f"Epoch {epoch+1}, D Loss: {d_loss_mean:.4f}, G Loss: {g_loss_mean:.4f}, W-dist: {w_distance_mean:.4f}, Time: {time.time() - start:.2f}s")

    print("Training finished.")

    return d_losses, g_losses, w_distances

# %%
def train(dataset, epochs):
    d_loss_hist, g_loss_hist, wasserstein_hist = [], [], []

    for epoch in range(epochs):
        start = time.time()
        d_losses, g_losses, w_distances = [], [], []

        for real_batch in dataset:
            d_loss, g_loss, w_distance = train_step(generator, discriminator, real_batch, gen_opt, disc_opt)
            d_losses.append(d_loss.numpy())
            g_losses.append(g_loss.numpy())
            w_distances.append(w_distance.numpy())

        d_loss_mean = np.mean(d_losses)
        g_loss_mean = np.mean(g_losses)
        w_distance_mean = np.mean(w_distances)
        d_loss_hist.append(d_loss_mean)
        g_loss_hist.append(g_loss_mean)
        wasserstein_hist.append(w_distance_mean)

        print(f"Epoch {epoch+1}, D Loss: {d_loss_mean:.4f}, G Loss: {g_loss_mean:.4f}, W-dist: {w_distance_mean:.4f}, Time: {time.time() - start:.2f}s")

    print("Training finished.")

    return d_loss_hist, g_loss_hist, wasserstein_hist  # <-- Return the histories

# %%
d_loss_hist, g_loss_hist, wasserstein_hist = train(dataset, epochs=EPOCHS)
# Out:
# Epoch 1, D Loss: 8.7411, G Loss: 0.0001, W-dist: -0.0011, Time: 30.71s
# Epoch 2, D Loss: 8.1914, G Loss: -0.0030, W-dist: -0.0038, Time: 40.94s
# Epoch 3, D Loss: 7.6305, G Loss: -0.0051, W-dist: -0.0070, Time: 30.57s
# Epoch 4, D Loss: 7.0527, G Loss: -0.0114, W-dist: -0.0126, Time: 30.08s
# Epoch 5, D Loss: 6.4521, G Loss: -0.0174, W-dist: -0.0182, Time: 30.24s
# Epoch 6, D Loss: 5.8206, G Loss: -0.0289, W-dist: -0.0259, Time: 30.26s
# Epoch 7, D Loss: 5.1617, G Loss: -0.0443, W-dist: -0.0336, Time: 30.17s
# Epoch 8, D Loss: 4.4709, G Loss: -0.0611, W-dist: -0.0409, Time: 40.94s
# Epoch 9, D Loss: 3.7717, G Loss: -0.0886, W-dist: -0.0578, Time: 30.44s
# Epoch 10, D Loss: 3.0721, G Loss: -0.1291, W-dist: -0.0840, Time: 29.38s
# Epoch 11, D Loss: 2.3815, G Loss: -0.1762, W-dist: -0.0998, Time: 30.95s
# Epoch 12, D Loss: 1.7527, G Loss: -0.2425, W-dist: -0.1284, Time: 40.94s
# Epoch 13, D Loss: 1.2227, G Loss: -0.3136, W-dist: -0.1736, Time: 30.35s
# Epoch 14, D Loss: 0.8357, G Loss: -0.4091, W-dist: -0.2273, Time: 40.94s
# Epoch 15, D Loss: 0.6074, G Loss: -0.5326, W-dist: -0.3011, Time: 30.20s
# Epoch 16, D Loss: 0.4780, G Loss: -0.6654, W-dist: -0.3345, Time: 40.94s
# Epoch 17, D Loss: 0.4846, G Loss: -0.7824, W-dist: -0.4173, Time: 30.32s
# Epoch 18, D Loss: 0.5372, G Loss: -0.9150, W-dist: -0.4982, Time: 40.94s
# Epoch 19, D Loss: 0.6496, G Loss: -1.0600, W-dist: -0.6199, Time: 30.16s
# Epoch 20, D Loss: 0.7478, G Loss: -1.1527, W-dist: -0.7209, Time: 40.94s
# Epoch 21, D Loss: 0.8368, G Loss: -1.3406, W-dist: -0.8090, Time: 30.33s
# Epoch 22, D Loss: 0.9032, G Loss: -1.4487, W-dist: -0.8718, Time: 40.94s
# Epoch 23, D Loss: 1.0088, G Loss: -1.6310, W-dist: -0.9718, Time: 30.54s
# Epoch 24, D Loss: 1.1844, G Loss: -1.7656, W-dist: -1.1409, Time: 31.18s
# Epoch 25, D Loss: 1.3282, G Loss: -1.9498, W-dist: -1.2706, Time: 30.14s
# Epoch 26, D Loss: 1.3719, G Loss: -2.0509, W-dist: -1.3064, Time: 30.64s
# Epoch 27, D Loss: 1.5012, G Loss: -2.3015, W-dist: -1.4150, Time: 30.12s
# Epoch 28, D Loss: 1.6424, G Loss: -2.4649, W-dist: -1.5341, Time: 30.80s
# Epoch 29, D Loss: 1.7794, G Loss: -2.5388, W-dist: -1.6342, Time: 29.70s
# Epoch 30, D Loss: 1.8724, G Loss: -2.6840, W-dist: -1.7012, Time: 30.52s
# Epoch 31, D Loss: 1.9836, G Loss: -2.8270, W-dist: -1.7787, Time: 40.94s
# Epoch 32, D Loss: 1.9476, G Loss: -2.8871, W-dist: -1.7329, Time: 40.94s
# Epoch 33, D Loss: 1.9893, G Loss: -2.9238, W-dist: -1.7431, Time: 30.03s
# Epoch 34, D Loss: 2.0437, G Loss: -2.9995, W-dist: -1.7575, Time: 30.91s
# Epoch 35, D Loss: 1.9699, G Loss: -2.9605, W-dist: -1.6678, Time: 30.69s
# Epoch 36, D Loss: 1.8730, G Loss: -2.9966, W-dist: -1.5582, Time: 30.05s
# Epoch 37, D Loss: 1.7420, G Loss: -2.9091, W-dist: -1.4244, Time: 30.63s
# Epoch 38, D Loss: 1.5444, G Loss: -2.8370, W-dist: -1.2512, Time: 29.99s
# Epoch 39, D Loss: 1.3018, G Loss: -2.6994, W-dist: -1.0130, Time: 31.62s
# Epoch 40, D Loss: 1.0749, G Loss: -2.5519, W-dist: -0.8084, Time: 40.94s
# Epoch 41, D Loss: 0.7866, G Loss: -2.3946, W-dist: -0.5360, Time: 30.56s
# Epoch 42, D Loss: 0.4733, G Loss: -2.2047, W-dist: -0.2631, Time: 31.18s
# Epoch 43, D Loss: 0.1457, G Loss: -1.9630, W-dist: 0.0333, Time: 30.31s
# Epoch 44, D Loss: -0.2162, G Loss: -1.6968, W-dist: 0.3652, Time: 40.94s
# Epoch 45, D Loss: -0.5559, G Loss: -1.4209, W-dist: 0.6845, Time: 30.43s
# Epoch 46, D Loss: -0.9116, G Loss: -1.1016, W-dist: 1.0121, Time: 40.94s
# Epoch 47, D Loss: -1.1845, G Loss: -0.8008, W-dist: 1.2609, Time: 30.26s
# Epoch 48, D Loss: -1.4750, G Loss: -0.4919, W-dist: 1.5494, Time: 30.88s
# Epoch 49, D Loss: -1.6774, G Loss: -0.1928, W-dist: 1.7590, Time: 30.44s
# Epoch 50, D Loss: -1.8607, G Loss: 0.0831, W-dist: 1.9497, Time: 31.34s
# Epoch 51, D Loss: -1.8665, G Loss: 0.2954, W-dist: 1.9726, Time: 40.94s
# Epoch 52, D Loss: -1.8852, G Loss: 0.4959, W-dist: 2.0048, Time: 31.15s
# Epoch 53, D Loss: -1.8451, G Loss: 0.5658, W-dist: 1.9880, Time: 31.42s
# Epoch 54, D Loss: -1.7594, G Loss: 0.6653, W-dist: 1.9072, Time: 31.33s
# Epoch 55, D Loss: -1.6259, G Loss: 0.7029, W-dist: 1.7820, Time: 31.31s
# Epoch 56, D Loss: -1.5245, G Loss: 0.6989, W-dist: 1.6667, Time: 40.94s
# Epoch 57, D Loss: -1.3764, G Loss: 0.6777, W-dist: 1.5216, Time: 31.38s
# Epoch 58, D Loss: -1.2593, G Loss: 0.6611, W-dist: 1.3925, Time: 31.44s
# Epoch 59, D Loss: -1.1268, G Loss: 0.6364, W-dist: 1.2456, Time: 30.72s
# Epoch 60, D Loss: -0.9961, G Loss: 0.5776, W-dist: 1.1025, Time: 31.14s
# Epoch 61, D Loss: -0.8803, G Loss: 0.5614, W-dist: 0.9658, Time: 40.94s
# Epoch 62, D Loss: -0.7528, G Loss: 0.5049, W-dist: 0.8220, Time: 30.87s
# Epoch 63, D Loss: -0.6766, G Loss: 0.4632, W-dist: 0.7319, Time: 40.95s
# Epoch 64, D Loss: -0.5501, G Loss: 0.4033, W-dist: 0.5929, Time: 40.95s
# Epoch 65, D Loss: -0.4635, G Loss: 0.3240, W-dist: 0.4970, Time: 30.40s
# Epoch 66, D Loss: -0.3719, G Loss: 0.2498, W-dist: 0.3969, Time: 30.78s
# Epoch 67, D Loss: -0.2651, G Loss: 0.1941, W-dist: 0.2856, Time: 30.96s
# Epoch 68, D Loss: -0.1637, G Loss: 0.0976, W-dist: 0.1798, Time: 30.99s
# Epoch 69, D Loss: -0.0885, G Loss: -0.0295, W-dist: 0.1034, Time: 30.56s
# Epoch 70, D Loss: -0.0158, G Loss: -0.1449, W-dist: 0.0291, Time: 30.45s
# Epoch 71, D Loss: 0.0389, G Loss: -0.2576, W-dist: -0.0274, Time: 31.18s
# Epoch 72, D Loss: 0.1346, G Loss: -0.4250, W-dist: -0.1229, Time: 30.91s
# Epoch 73, D Loss: 0.1838, G Loss: -0.6190, W-dist: -0.1720, Time: 30.22s
# Epoch 74, D Loss: 0.2385, G Loss: -0.8722, W-dist: -0.2268, Time: 31.04s
# Epoch 75, D Loss: 0.2558, G Loss: -1.2370, W-dist: -0.2477, Time: 30.43s
# Epoch 76, D Loss: 0.2288, G Loss: -1.6274, W-dist: -0.2249, Time: 31.61s
# Epoch 77, D Loss: 0.1765, G Loss: -1.8681, W-dist: -0.1698, Time: 40.94s
# Epoch 78, D Loss: 0.1924, G Loss: -1.9751, W-dist: -0.1804, Time: 30.81s
# Epoch 79, D Loss: 0.1520, G Loss: -2.0270, W-dist: -0.1370, Time: 30.92s
# Epoch 80, D Loss: 0.0907, G Loss: -2.0185, W-dist: -0.0764, Time: 30.81s
# Epoch 81, D Loss: 0.0532, G Loss: -1.9807, W-dist: -0.0402, Time: 31.34s
# Epoch 82, D Loss: 0.0333, G Loss: -1.9030, W-dist: -0.0203, Time: 30.65s
# Epoch 83, D Loss: -0.0238, G Loss: -1.8430, W-dist: 0.0358, Time: 31.53s
# Epoch 84, D Loss: -0.0836, G Loss: -1.7910, W-dist: 0.0954, Time: 30.81s
# Epoch 85, D Loss: -0.1364, G Loss: -1.6964, W-dist: 0.1480, Time: 30.40s
# Epoch 86, D Loss: -0.1659, G Loss: -1.6104, W-dist: 0.1781, Time: 30.80s
# Epoch 87, D Loss: -0.2117, G Loss: -1.5079, W-dist: 0.2247, Time: 30.37s
# Epoch 88, D Loss: -0.2545, G Loss: -1.4179, W-dist: 0.2673, Time: 31.13s
# Epoch 89, D Loss: -0.2991, G Loss: -1.3229, W-dist: 0.3135, Time: 40.94s
# Epoch 90, D Loss: -0.3249, G Loss: -1.2416, W-dist: 0.3397, Time: 32.09s
# Epoch 91, D Loss: -0.3536, G Loss: -1.1707, W-dist: 0.3690, Time: 31.04s
# Epoch 92, D Loss: -0.3794, G Loss: -1.0547, W-dist: 0.3957, Time: 30.70s
# Epoch 93, D Loss: -0.3816, G Loss: -1.0066, W-dist: 0.3980, Time: 31.54s
# Epoch 94, D Loss: -0.4006, G Loss: -0.9357, W-dist: 0.4173, Time: 40.94s
# Epoch 95, D Loss: -0.4037, G Loss: -0.8921, W-dist: 0.4198, Time: 30.88s
# Epoch 96, D Loss: -0.3841, G Loss: -0.8759, W-dist: 0.4004, Time: 40.94s
# Epoch 97, D Loss: -0.3769, G Loss: -0.8666, W-dist: 0.3923, Time: 31.67s
# Epoch 98, D Loss: -0.3504, G Loss: -0.8445, W-dist: 0.3648, Time: 30.89s
# Epoch 99, D Loss: -0.3453, G Loss: -0.8660, W-dist: 0.3601, Time: 30.57s
# Epoch 100, D Loss: -0.3372, G Loss: -0.8783, W-dist: 0.3512, Time: 31.11s
# Epoch 101, D Loss: -0.3202, G Loss: -0.9079, W-dist: 0.3324, Time: 30.65s
# Epoch 102, D Loss: -0.2955, G Loss: -0.9445, W-dist: 0.3080, Time: 30.99s
# Epoch 103, D Loss: -0.2726, G Loss: -0.9888, W-dist: 0.2843, Time: 40.95s
# Epoch 104, D Loss: -0.2678, G Loss: -1.0339, W-dist: 0.2786, Time: 40.95s
# Epoch 105, D Loss: -0.2403, G Loss: -1.0876, W-dist: 0.2506, Time: 31.37s
# Epoch 106, D Loss: -0.2389, G Loss: -1.1686, W-dist: 0.2486, Time: 30.73s
# Epoch 107, D Loss: -0.2184, G Loss: -1.2022, W-dist: 0.2287, Time: 31.52s
# Epoch 108, D Loss: -0.2086, G Loss: -1.2768, W-dist: 0.2187, Time: 30.57s
# Epoch 109, D Loss: -0.1931, G Loss: -1.3216, W-dist: 0.2027, Time: 31.09s
# Epoch 110, D Loss: -0.1704, G Loss: -1.3541, W-dist: 0.1796, Time: 40.94s
# Epoch 111, D Loss: -0.1716, G Loss: -1.4415, W-dist: 0.1822, Time: 31.21s
# Epoch 112, D Loss: -0.1460, G Loss: -1.4732, W-dist: 0.1554, Time: 40.94s
# Epoch 113, D Loss: -0.1338, G Loss: -1.5250, W-dist: 0.1435, Time: 30.62s
# Epoch 114, D Loss: -0.1243, G Loss: -1.5748, W-dist: 0.1341, Time: 30.82s
# Epoch 115, D Loss: -0.1135, G Loss: -1.6214, W-dist: 0.1239, Time: 30.75s
# Epoch 116, D Loss: -0.1166, G Loss: -1.6777, W-dist: 0.1279, Time: 31.04s
# Epoch 117, D Loss: -0.0933, G Loss: -1.7046, W-dist: 0.1044, Time: 30.68s
# Epoch 118, D Loss: -0.1099, G Loss: -1.7407, W-dist: 0.1217, Time: 31.17s
# Epoch 119, D Loss: -0.1013, G Loss: -1.7541, W-dist: 0.1124, Time: 31.65s
# Epoch 120, D Loss: -0.0914, G Loss: -1.7837, W-dist: 0.1035, Time: 30.65s
# Epoch 121, D Loss: -0.1110, G Loss: -1.7837, W-dist: 0.1229, Time: 30.88s
# Epoch 122, D Loss: -0.1048, G Loss: -1.7589, W-dist: 0.1168, Time: 30.32s
# Epoch 123, D Loss: -0.1284, G Loss: -1.6933, W-dist: 0.1418, Time: 31.16s
# Epoch 124, D Loss: -0.1522, G Loss: -1.6412, W-dist: 0.1660, Time: 31.24s
# Epoch 125, D Loss: -0.1792, G Loss: -1.5506, W-dist: 0.1932, Time: 30.73s
# Epoch 126, D Loss: -0.1984, G Loss: -1.3927, W-dist: 0.2129, Time: 32.10s
# Epoch 127, D Loss: -0.1987, G Loss: -1.2393, W-dist: 0.2118, Time: 31.02s
# Epoch 128, D Loss: -0.2051, G Loss: -1.0460, W-dist: 0.2190, Time: 40.94s
# Epoch 129, D Loss: -0.1970, G Loss: -0.8883, W-dist: 0.2105, Time: 31.46s
# Epoch 130, D Loss: -0.1544, G Loss: -0.7322, W-dist: 0.1683, Time: 31.13s
# Epoch 131, D Loss: -0.1073, G Loss: -0.6660, W-dist: 0.1225, Time: 31.55s
# Epoch 132, D Loss: -0.0720, G Loss: -0.6674, W-dist: 0.0915, Time: 30.51s
# Epoch 133, D Loss: -0.0634, G Loss: -0.7425, W-dist: 0.0907, Time: 31.14s
# Epoch 134, D Loss: -0.0590, G Loss: -0.8416, W-dist: 0.0957, Time: 32.15s
# Epoch 135, D Loss: -0.0918, G Loss: -0.9727, W-dist: 0.1401, Time: 30.64s
# Epoch 136, D Loss: -0.1316, G Loss: -1.1024, W-dist: 0.1835, Time: 31.59s
# Epoch 137, D Loss: -0.1750, G Loss: -1.2326, W-dist: 0.2339, Time: 31.87s
# Epoch 138, D Loss: -0.2347, G Loss: -1.3204, W-dist: 0.2970, Time: 31.10s
# Epoch 139, D Loss: -0.2682, G Loss: -1.3562, W-dist: 0.3234, Time: 31.83s
# Epoch 140, D Loss: -0.3195, G Loss: -1.3714, W-dist: 0.3635, Time: 40.94s
# Epoch 141, D Loss: -0.3229, G Loss: -1.3672, W-dist: 0.3661, Time: 31.45s
# Epoch 142, D Loss: -0.3164, G Loss: -1.3575, W-dist: 0.3548, Time: 31.58s
# Epoch 143, D Loss: -0.2827, G Loss: -1.3532, W-dist: 0.3171, Time: 30.70s
# Epoch 144, D Loss: -0.2350, G Loss: -1.3113, W-dist: 0.2645, Time: 30.92s
# Epoch 145, D Loss: -0.1932, G Loss: -1.1978, W-dist: 0.2195, Time: 40.94s
# Epoch 146, D Loss: -0.1459, G Loss: -0.9032, W-dist: 0.1698, Time: 30.98s
# Epoch 147, D Loss: -0.2005, G Loss: -0.2742, W-dist: 0.2120, Time: 40.94s
# Epoch 148, D Loss: -0.2535, G Loss: 0.4976, W-dist: 0.2641, Time: 31.88s
# Epoch 149, D Loss: -0.2619, G Loss: 0.8310, W-dist: 0.2862, Time: 31.47s
# Epoch 150, D Loss: -0.2655, G Loss: 0.8497, W-dist: 0.2905, Time: 30.69s
# Epoch 151, D Loss: -0.2748, G Loss: 0.7856, W-dist: 0.2956, Time: 31.07s
# Epoch 152, D Loss: -0.2822, G Loss: 0.7461, W-dist: 0.3048, Time: 30.50s
# Epoch 153, D Loss: -0.2651, G Loss: 0.6562, W-dist: 0.2848, Time: 31.21s
# Epoch 154, D Loss: -0.2742, G Loss: 0.5806, W-dist: 0.2899, Time: 31.01s
# Epoch 155, D Loss: -0.2563, G Loss: 0.4477, W-dist: 0.2700, Time: 31.17s
# Epoch 156, D Loss: -0.2511, G Loss: 0.3569, W-dist: 0.2620, Time: 31.25s
# Epoch 157, D Loss: -0.2677, G Loss: 0.2625, W-dist: 0.2757, Time: 30.60s
# Epoch 158, D Loss: -0.2185, G Loss: 0.1774, W-dist: 0.2273, Time: 31.25s
# Epoch 159, D Loss: -0.1721, G Loss: 0.0205, W-dist: 0.1835, Time: 30.98s
# Epoch 160, D Loss: -0.1952, G Loss: -0.0495, W-dist: 0.2050, Time: 30.91s
# Epoch 161, D Loss: -0.1777, G Loss: -0.2080, W-dist: 0.1880, Time: 31.44s
# Epoch 162, D Loss: -0.1953, G Loss: -0.3344, W-dist: 0.2062, Time: 31.63s
# Epoch 163, D Loss: -0.2044, G Loss: -0.4616, W-dist: 0.2147, Time: 31.46s
# Epoch 164, D Loss: -0.1849, G Loss: -0.5672, W-dist: 0.1987, Time: 31.49s
# Epoch 165, D Loss: -0.1901, G Loss: -0.7254, W-dist: 0.2013, Time: 30.78s
# Epoch 166, D Loss: -0.1837, G Loss: -0.8460, W-dist: 0.1950, Time: 31.05s
# Epoch 167, D Loss: -0.1756, G Loss: -0.9892, W-dist: 0.1869, Time: 31.22s
# Epoch 168, D Loss: -0.1443, G Loss: -1.0050, W-dist: 0.1538, Time: 30.69s
# Epoch 169, D Loss: -0.1572, G Loss: -1.0723, W-dist: 0.1644, Time: 31.52s
# Epoch 170, D Loss: -0.1301, G Loss: -1.1004, W-dist: 0.1367, Time: 40.95s
# Epoch 171, D Loss: -0.1085, G Loss: -1.1780, W-dist: 0.1178, Time: 30.98s
# Epoch 172, D Loss: -0.1056, G Loss: -1.1308, W-dist: 0.1123, Time: 40.94s
# Epoch 173, D Loss: -0.0949, G Loss: -1.1200, W-dist: 0.1020, Time: 30.75s
# Epoch 174, D Loss: -0.0929, G Loss: -1.1685, W-dist: 0.1011, Time: 30.97s
# Epoch 175, D Loss: -0.0794, G Loss: -1.2225, W-dist: 0.0896, Time: 30.14s
# Epoch 176, D Loss: -0.0942, G Loss: -1.3041, W-dist: 0.1127, Time: 40.94s
# Epoch 177, D Loss: -0.1100, G Loss: -1.2674, W-dist: 0.1199, Time: 30.97s
# Epoch 178, D Loss: -0.0912, G Loss: -1.3875, W-dist: 0.1115, Time: 30.77s
# Epoch 179, D Loss: -0.0881, G Loss: -1.4760, W-dist: 0.1002, Time: 30.31s
# Epoch 180, D Loss: -0.0995, G Loss: -1.5164, W-dist: 0.1113, Time: 40.94s
# Epoch 181, D Loss: -0.0704, G Loss: -1.6832, W-dist: 0.1111, Time: 29.99s
# Epoch 182, D Loss: -0.0909, G Loss: -1.7666, W-dist: 0.1102, Time: 30.98s
# Epoch 183, D Loss: -0.0773, G Loss: -1.9681, W-dist: 0.0958, Time: 30.65s
# Epoch 184, D Loss: -0.1090, G Loss: -2.0202, W-dist: 0.1308, Time: 31.40s
# Epoch 185, D Loss: -0.1149, G Loss: -2.1803, W-dist: 0.1457, Time: 31.63s
# Epoch 186, D Loss: -0.1067, G Loss: -2.2652, W-dist: 0.1307, Time: 30.76s
# Epoch 187, D Loss: -0.1076, G Loss: -2.3938, W-dist: 0.1458, Time: 30.71s
# Epoch 188, D Loss: -0.1037, G Loss: -2.4500, W-dist: 0.1448, Time: 31.08s
# Epoch 189, D Loss: -0.1021, G Loss: -2.4136, W-dist: 0.1217, Time: 30.80s
# Epoch 190, D Loss: -0.0851, G Loss: -2.5597, W-dist: 0.1213, Time: 31.26s
# Epoch 191, D Loss: -0.0759, G Loss: -2.4644, W-dist: 0.1037, Time: 30.82s
# Epoch 192, D Loss: -0.0661, G Loss: -2.3679, W-dist: 0.0876, Time: 30.87s
# Epoch 193, D Loss: -0.0796, G Loss: -2.2910, W-dist: 0.0997, Time: 31.36s
# Epoch 194, D Loss: -0.0846, G Loss: -2.2881, W-dist: 0.0991, Time: 30.31s
# Epoch 195, D Loss: -0.0852, G Loss: -2.2742, W-dist: 0.0990, Time: 31.14s
# Epoch 196, D Loss: -0.0810, G Loss: -2.3337, W-dist: 0.0993, Time: 30.85s
# Epoch 197, D Loss: -0.0872, G Loss: -2.3159, W-dist: 0.1013, Time: 31.40s
# Epoch 198, D Loss: -0.1100, G Loss: -2.4890, W-dist: 0.1340, Time: 31.60s
# Epoch 199, D Loss: -0.1164, G Loss: -2.5618, W-dist: 0.1382, Time: 31.85s
# Epoch 200, D Loss: -0.1056, G Loss: -2.6282, W-dist: 0.1250, Time: 31.22s
# Epoch 201, D Loss: -0.0973, G Loss: -2.6854, W-dist: 0.1211, Time: 31.91s
# Epoch 202, D Loss: -0.1081, G Loss: -2.6745, W-dist: 0.1255, Time: 30.71s
# Epoch 203, D Loss: -0.1093, G Loss: -2.7274, W-dist: 0.1296, Time: 31.42s
# Epoch 204, D Loss: -0.1062, G Loss: -2.6202, W-dist: 0.1235, Time: 40.94s
# Epoch 205, D Loss: -0.0808, G Loss: -2.6209, W-dist: 0.1030, Time: 31.35s
# Epoch 206, D Loss: -0.0955, G Loss: -2.4316, W-dist: 0.1101, Time: 32.05s
# Epoch 207, D Loss: -0.0761, G Loss: -2.2606, W-dist: 0.0912, Time: 30.87s
# Epoch 208, D Loss: -0.1009, G Loss: -2.1649, W-dist: 0.1150, Time: 31.58s
# Epoch 209, D Loss: -0.1040, G Loss: -1.9886, W-dist: 0.1217, Time: 32.28s
# Epoch 210, D Loss: -0.0895, G Loss: -2.0297, W-dist: 0.1090, Time: 31.19s
# Epoch 211, D Loss: -0.1340, G Loss: -1.9122, W-dist: 0.1530, Time: 31.34s
# Epoch 212, D Loss: -0.1422, G Loss: -1.8617, W-dist: 0.1695, Time: 40.94s
# Epoch 213, D Loss: -0.1526, G Loss: -1.7886, W-dist: 0.1825, Time: 31.43s
# Epoch 214, D Loss: -0.1461, G Loss: -1.5966, W-dist: 0.1746, Time: 31.86s
# Epoch 215, D Loss: -0.1635, G Loss: -1.5883, W-dist: 0.1919, Time: 31.48s
# Epoch 216, D Loss: -0.1558, G Loss: -1.4768, W-dist: 0.1768, Time: 31.94s
# Epoch 217, D Loss: -0.1493, G Loss: -1.5446, W-dist: 0.1740, Time: 32.21s
# Epoch 218, D Loss: -0.1808, G Loss: -1.4787, W-dist: 0.2013, Time: 31.13s
# Epoch 219, D Loss: -0.1437, G Loss: -1.4641, W-dist: 0.1801, Time: 31.62s
# Epoch 220, D Loss: -0.1486, G Loss: -1.4686, W-dist: 0.1779, Time: 32.16s
# Epoch 221, D Loss: -0.1466, G Loss: -1.4352, W-dist: 0.1760, Time: 30.97s
# Epoch 222, D Loss: -0.1529, G Loss: -1.4696, W-dist: 0.1861, Time: 31.67s
# Epoch 223, D Loss: -0.1347, G Loss: -1.4398, W-dist: 0.1679, Time: 30.72s
# Epoch 224, D Loss: -0.1459, G Loss: -1.5186, W-dist: 0.1754, Time: 31.10s
# Epoch 225, D Loss: -0.1658, G Loss: -1.4563, W-dist: 0.1985, Time: 31.47s
# Epoch 226, D Loss: -0.1342, G Loss: -1.4613, W-dist: 0.1684, Time: 30.43s
# Epoch 227, D Loss: -0.1615, G Loss: -1.5129, W-dist: 0.2032, Time: 31.99s
# Epoch 228, D Loss: -0.1399, G Loss: -1.4672, W-dist: 0.1748, Time: 40.94s
# Epoch 229, D Loss: -0.1774, G Loss: -1.5400, W-dist: 0.2139, Time: 31.28s
# Epoch 230, D Loss: -0.1618, G Loss: -1.4850, W-dist: 0.1946, Time: 31.08s
# Epoch 231, D Loss: -0.1769, G Loss: -1.5664, W-dist: 0.2151, Time: 30.40s
# Epoch 232, D Loss: -0.1610, G Loss: -1.5007, W-dist: 0.1958, Time: 31.06s
# Epoch 233, D Loss: -0.1618, G Loss: -1.4246, W-dist: 0.1967, Time: 30.69s
# Epoch 234, D Loss: -0.1472, G Loss: -1.4210, W-dist: 0.1785, Time: 31.71s
# Epoch 235, D Loss: -0.1519, G Loss: -1.3987, W-dist: 0.1804, Time: 31.36s
# Epoch 236, D Loss: -0.1542, G Loss: -1.3417, W-dist: 0.1852, Time: 30.91s
# Epoch 237, D Loss: -0.1543, G Loss: -1.2888, W-dist: 0.1815, Time: 31.18s
# Epoch 238, D Loss: -0.1407, G Loss: -1.3575, W-dist: 0.1695, Time: 40.94s
# Epoch 239, D Loss: -0.1559, G Loss: -1.3853, W-dist: 0.1829, Time: 31.20s
# Epoch 240, D Loss: -0.1541, G Loss: -1.4162, W-dist: 0.1813, Time: 31.11s
# Epoch 241, D Loss: -0.1607, G Loss: -1.4508, W-dist: 0.1827, Time: 31.27s
# Epoch 242, D Loss: -0.1803, G Loss: -1.6495, W-dist: 0.2106, Time: 31.22s
# Epoch 243, D Loss: -0.1812, G Loss: -1.6210, W-dist: 0.2071, Time: 40.94s
# Epoch 244, D Loss: -0.1797, G Loss: -1.6422, W-dist: 0.2045, Time: 31.25s
# Epoch 245, D Loss: -0.1553, G Loss: -1.7397, W-dist: 0.1814, Time: 31.01s
# Epoch 246, D Loss: -0.1787, G Loss: -1.7912, W-dist: 0.2010, Time: 30.58s
# Epoch 247, D Loss: -0.1783, G Loss: -1.7714, W-dist: 0.2017, Time: 30.94s
# Epoch 248, D Loss: -0.1790, G Loss: -1.7672, W-dist: 0.2017, Time: 31.10s
# Epoch 249, D Loss: -0.1772, G Loss: -1.7782, W-dist: 0.2001, Time: 31.55s
# Epoch 250, D Loss: -0.1724, G Loss: -1.7849, W-dist: 0.1933, Time: 40.94s
# Epoch 251, D Loss: -0.1811, G Loss: -1.7787, W-dist: 0.2033, Time: 30.96s
# Epoch 252, D Loss: -0.1929, G Loss: -1.7437, W-dist: 0.2124, Time: 31.29s
# Epoch 253, D Loss: -0.1701, G Loss: -1.7204, W-dist: 0.1894, Time: 30.31s
# Epoch 254, D Loss: -0.1812, G Loss: -1.7061, W-dist: 0.1998, Time: 31.05s
# Epoch 255, D Loss: -0.1922, G Loss: -1.6788, W-dist: 0.2068, Time: 40.94s
# Epoch 256, D Loss: -0.1811, G Loss: -1.6384, W-dist: 0.1965, Time: 31.49s
# Epoch 257, D Loss: -0.1876, G Loss: -1.6193, W-dist: 0.2027, Time: 31.58s
# Epoch 258, D Loss: -0.1780, G Loss: -1.6473, W-dist: 0.1935, Time: 31.07s
# Epoch 259, D Loss: -0.1929, G Loss: -1.6346, W-dist: 0.2090, Time: 31.38s
# Epoch 260, D Loss: -0.1832, G Loss: -1.6400, W-dist: 0.2001, Time: 40.94s
# Epoch 261, D Loss: -0.1884, G Loss: -1.6405, W-dist: 0.2056, Time: 31.39s
# Epoch 262, D Loss: -0.1839, G Loss: -1.6285, W-dist: 0.1994, Time: 31.44s
# Epoch 263, D Loss: -0.1837, G Loss: -1.6279, W-dist: 0.1949, Time: 30.55s
# Epoch 264, D Loss: -0.1985, G Loss: -1.6382, W-dist: 0.2156, Time: 31.03s
# Epoch 265, D Loss: -0.1780, G Loss: -1.6294, W-dist: 0.1924, Time: 30.52s
# Epoch 266, D Loss: -0.1954, G Loss: -1.6382, W-dist: 0.2129, Time: 31.08s
# Epoch 267, D Loss: -0.1932, G Loss: -1.6272, W-dist: 0.2085, Time: 30.94s
# Epoch 268, D Loss: -0.1991, G Loss: -1.6260, W-dist: 0.2203, Time: 30.92s
# Epoch 269, D Loss: -0.1885, G Loss: -1.6533, W-dist: 0.2072, Time: 31.05s
# Epoch 270, D Loss: -0.2022, G Loss: -1.6618, W-dist: 0.2207, Time: 30.63s
# Epoch 271, D Loss: -0.1829, G Loss: -1.6503, W-dist: 0.2016, Time: 31.42s
# Epoch 272, D Loss: -0.1906, G Loss: -1.6427, W-dist: 0.2099, Time: 30.96s
# Epoch 273, D Loss: -0.1918, G Loss: -1.6590, W-dist: 0.2128, Time: 30.43s
# Epoch 274, D Loss: -0.1810, G Loss: -1.6559, W-dist: 0.2027, Time: 31.23s
# Epoch 275, D Loss: -0.1877, G Loss: -1.7028, W-dist: 0.2131, Time: 30.13s
# Epoch 276, D Loss: -0.1682, G Loss: -1.7138, W-dist: 0.1918, Time: 30.99s
# Epoch 277, D Loss: -0.1650, G Loss: -1.7540, W-dist: 0.1937, Time: 40.94s
# Epoch 278, D Loss: -0.1685, G Loss: -1.7175, W-dist: 0.1925, Time: 31.84s
# Epoch 279, D Loss: -0.1781, G Loss: -1.7298, W-dist: 0.2025, Time: 31.17s
# Epoch 280, D Loss: -0.1644, G Loss: -1.7224, W-dist: 0.1909, Time: 30.47s
# Epoch 281, D Loss: -0.1717, G Loss: -1.7187, W-dist: 0.1989, Time: 31.30s
# Epoch 282, D Loss: -0.1597, G Loss: -1.7261, W-dist: 0.1904, Time: 30.70s
# Epoch 283, D Loss: -0.1681, G Loss: -1.7429, W-dist: 0.2044, Time: 30.99s
# Epoch 284, D Loss: -0.1559, G Loss: -1.7790, W-dist: 0.1924, Time: 31.18s
# Epoch 285, D Loss: -0.1786, G Loss: -1.8080, W-dist: 0.2118, Time: 30.87s
# Epoch 286, D Loss: -0.1506, G Loss: -1.7945, W-dist: 0.1848, Time: 30.87s
# Epoch 287, D Loss: -0.1533, G Loss: -1.8076, W-dist: 0.1829, Time: 30.49s
# Epoch 288, D Loss: -0.1552, G Loss: -1.8017, W-dist: 0.1883, Time: 30.95s
# Epoch 289, D Loss: -0.1568, G Loss: -1.8085, W-dist: 0.1868, Time: 30.96s
# Epoch 290, D Loss: -0.1417, G Loss: -1.8152, W-dist: 0.1717, Time: 30.50s
# Epoch 291, D Loss: -0.1216, G Loss: -1.8090, W-dist: 0.1567, Time: 31.02s
# Epoch 292, D Loss: -0.1596, G Loss: -1.8187, W-dist: 0.1996, Time: 30.57s
# Epoch 293, D Loss: -0.1400, G Loss: -1.8047, W-dist: 0.1744, Time: 32.02s
# Epoch 294, D Loss: -0.1452, G Loss: -1.8020, W-dist: 0.1827, Time: 31.23s
# Epoch 295, D Loss: -0.1280, G Loss: -1.8197, W-dist: 0.1665, Time: 30.55s
# Epoch 296, D Loss: -0.1209, G Loss: -1.8010, W-dist: 0.1686, Time: 40.94s
# Epoch 297, D Loss: -0.1474, G Loss: -1.8224, W-dist: 0.1819, Time: 30.46s
# Epoch 298, D Loss: -0.1240, G Loss: -1.8150, W-dist: 0.1649, Time: 31.44s
# Epoch 299, D Loss: -0.1216, G Loss: -1.8521, W-dist: 0.1625, Time: 40.94s
# Epoch 300, D Loss: -0.1311, G Loss: -1.8628, W-dist: 0.1806, Time: 31.19s
# Epoch 301, D Loss: -0.1290, G Loss: -1.8602, W-dist: 0.1704, Time: 31.93s
# Epoch 302, D Loss: -0.1292, G Loss: -1.8702, W-dist: 0.1701, Time: 30.53s
# Epoch 303, D Loss: -0.1143, G Loss: -1.8445, W-dist: 0.1609, Time: 31.13s
# Epoch 304, D Loss: -0.1228, G Loss: -1.8404, W-dist: 0.1644, Time: 30.48s
# Epoch 305, D Loss: -0.1174, G Loss: -1.8369, W-dist: 0.1587, Time: 31.14s
# Epoch 306, D Loss: -0.1220, G Loss: -1.8630, W-dist: 0.1679, Time: 31.28s
# Epoch 307, D Loss: -0.1000, G Loss: -1.8946, W-dist: 0.1429, Time: 30.34s
# Epoch 308, D Loss: -0.1175, G Loss: -1.9576, W-dist: 0.1639, Time: 31.11s
# Epoch 309, D Loss: -0.1130, G Loss: -1.9244, W-dist: 0.1621, Time: 40.94s
# Epoch 310, D Loss: -0.1066, G Loss: -1.9462, W-dist: 0.1503, Time: 31.16s
# Epoch 311, D Loss: -0.0919, G Loss: -1.9263, W-dist: 0.1359, Time: 40.94s
# Epoch 312, D Loss: -0.1038, G Loss: -1.9244, W-dist: 0.1529, Time: 31.14s
# Epoch 313, D Loss: -0.0935, G Loss: -1.9623, W-dist: 0.1417, Time: 30.96s
# Epoch 314, D Loss: -0.1017, G Loss: -1.9413, W-dist: 0.1539, Time: 30.61s
# Epoch 315, D Loss: -0.0824, G Loss: -1.9231, W-dist: 0.1246, Time: 31.25s
# Epoch 316, D Loss: -0.0840, G Loss: -1.8973, W-dist: 0.1301, Time: 31.34s
# Epoch 317, D Loss: -0.0879, G Loss: -1.8258, W-dist: 0.1363, Time: 31.62s
# Epoch 318, D Loss: -0.0892, G Loss: -1.7671, W-dist: 0.1321, Time: 32.12s
# Epoch 319, D Loss: -0.1022, G Loss: -1.7042, W-dist: 0.1454, Time: 30.81s
# Epoch 320, D Loss: -0.0923, G Loss: -1.6408, W-dist: 0.1364, Time: 31.76s
# Epoch 321, D Loss: -0.0844, G Loss: -1.6164, W-dist: 0.1306, Time: 31.38s
# Epoch 322, D Loss: -0.1157, G Loss: -1.6175, W-dist: 0.1602, Time: 30.78s
# Epoch 323, D Loss: -0.1263, G Loss: -1.6143, W-dist: 0.1656, Time: 31.03s
# Epoch 324, D Loss: -0.1120, G Loss: -1.6336, W-dist: 0.1562, Time: 31.55s
# Epoch 325, D Loss: -0.1355, G Loss: -1.6490, W-dist: 0.1765, Time: 31.60s
# Epoch 326, D Loss: -0.1276, G Loss: -1.6345, W-dist: 0.1705, Time: 31.35s
# Epoch 327, D Loss: -0.1224, G Loss: -1.6790, W-dist: 0.1594, Time: 30.74s
# Epoch 328, D Loss: -0.1153, G Loss: -1.6984, W-dist: 0.1530, Time: 32.33s
# Epoch 329, D Loss: -0.1024, G Loss: -1.6769, W-dist: 0.1365, Time: 31.75s
# Epoch 330, D Loss: -0.1063, G Loss: -1.6832, W-dist: 0.1378, Time: 31.28s
# Epoch 331, D Loss: -0.1295, G Loss: -1.6631, W-dist: 0.1567, Time: 31.53s
# Epoch 332, D Loss: -0.1319, G Loss: -1.6072, W-dist: 0.1587, Time: 32.14s
# Epoch 333, D Loss: -0.1302, G Loss: -1.5602, W-dist: 0.1571, Time: 31.07s
# Epoch 334, D Loss: -0.1355, G Loss: -1.5377, W-dist: 0.1635, Time: 31.38s
# Epoch 335, D Loss: -0.1259, G Loss: -1.4999, W-dist: 0.1529, Time: 30.89s
# Epoch 336, D Loss: -0.1338, G Loss: -1.5002, W-dist: 0.1559, Time: 31.22s
# Epoch 337, D Loss: -0.1237, G Loss: -1.4441, W-dist: 0.1512, Time: 31.15s
# Epoch 338, D Loss: -0.1319, G Loss: -1.3935, W-dist: 0.1614, Time: 30.71s
# Epoch 339, D Loss: -0.1170, G Loss: -1.3690, W-dist: 0.1493, Time: 31.69s
# Epoch 340, D Loss: -0.1363, G Loss: -1.3322, W-dist: 0.1681, Time: 32.22s
# Epoch 341, D Loss: -0.1480, G Loss: -1.3119, W-dist: 0.1850, Time: 31.17s
# Epoch 342, D Loss: -0.1622, G Loss: -1.3243, W-dist: 0.2081, Time: 31.36s
# Epoch 343, D Loss: -0.1476, G Loss: -1.3477, W-dist: 0.1835, Time: 40.94s
# Epoch 344, D Loss: -0.1591, G Loss: -1.3787, W-dist: 0.1948, Time: 31.76s
# Epoch 345, D Loss: -0.1459, G Loss: -1.4071, W-dist: 0.1906, Time: 31.74s
# Epoch 346, D Loss: -0.1341, G Loss: -1.4166, W-dist: 0.1779, Time: 31.22s
# Epoch 347, D Loss: -0.1474, G Loss: -1.3703, W-dist: 0.1891, Time: 32.36s
# Epoch 348, D Loss: -0.1807, G Loss: -1.3055, W-dist: 0.2241, Time: 32.87s
# Epoch 349, D Loss: -0.1856, G Loss: -1.2317, W-dist: 0.2240, Time: 31.03s
# Epoch 350, D Loss: -0.2027, G Loss: -1.1362, W-dist: 0.2373, Time: 31.83s
# Epoch 351, D Loss: -0.1996, G Loss: -1.0526, W-dist: 0.2438, Time: 31.55s
# Epoch 352, D Loss: -0.1954, G Loss: -0.9870, W-dist: 0.2330, Time: 31.05s
# Epoch 353, D Loss: -0.1737, G Loss: -0.9461, W-dist: 0.2166, Time: 31.73s
# Epoch 354, D Loss: -0.1704, G Loss: -0.9479, W-dist: 0.2200, Time: 31.75s
# Epoch 355, D Loss: -0.1797, G Loss: -0.9442, W-dist: 0.2308, Time: 31.35s
# Epoch 356, D Loss: -0.2240, G Loss: -0.9284, W-dist: 0.2785, Time: 32.74s
# Epoch 357, D Loss: -0.2507, G Loss: -0.9371, W-dist: 0.3134, Time: 31.85s
# Epoch 358, D Loss: -0.2624, G Loss: -0.9398, W-dist: 0.3158, Time: 40.94s
# Epoch 359, D Loss: -0.2770, G Loss: -0.9155, W-dist: 0.3275, Time: 32.10s
# Epoch 360, D Loss: -0.2771, G Loss: -0.8883, W-dist: 0.3260, Time: 32.22s
# Epoch 361, D Loss: -0.2598, G Loss: -0.8614, W-dist: 0.3115, Time: 31.33s
# Epoch 362, D Loss: -0.2564, G Loss: -0.7930, W-dist: 0.3108, Time: 31.97s
# Epoch 363, D Loss: -0.2695, G Loss: -0.7366, W-dist: 0.3119, Time: 31.81s
# Epoch 364, D Loss: -0.2722, G Loss: -0.6286, W-dist: 0.3173, Time: 31.64s
# Epoch 365, D Loss: -0.2992, G Loss: -0.5435, W-dist: 0.3382, Time: 31.65s
# Epoch 366, D Loss: -0.3017, G Loss: -0.4769, W-dist: 0.3412, Time: 40.94s
# Epoch 367, D Loss: -0.2985, G Loss: -0.4480, W-dist: 0.3390, Time: 31.42s
# Epoch 368, D Loss: -0.2982, G Loss: -0.3988, W-dist: 0.3320, Time: 32.03s
# Epoch 369, D Loss: -0.2708, G Loss: -0.3535, W-dist: 0.3079, Time: 30.77s
# Epoch 370, D Loss: -0.2650, G Loss: -0.3667, W-dist: 0.3016, Time: 31.77s
# Epoch 371, D Loss: -0.2492, G Loss: -0.3734, W-dist: 0.2883, Time: 32.20s
# Epoch 372, D Loss: -0.2438, G Loss: -0.3658, W-dist: 0.2941, Time: 31.75s
# Epoch 373, D Loss: -0.2514, G Loss: -0.3255, W-dist: 0.2872, Time: 31.71s
# Epoch 374, D Loss: -0.2687, G Loss: -0.3232, W-dist: 0.3036, Time: 31.90s
# Epoch 375, D Loss: -0.2699, G Loss: -0.3625, W-dist: 0.3063, Time: 30.94s
# Epoch 376, D Loss: -0.2679, G Loss: -0.4058, W-dist: 0.3103, Time: 31.77s
# Epoch 377, D Loss: -0.2575, G Loss: -0.4354, W-dist: 0.2970, Time: 40.94s
# Epoch 378, D Loss: -0.2479, G Loss: -0.4565, W-dist: 0.2868, Time: 31.80s
# Epoch 379, D Loss: -0.2410, G Loss: -0.4772, W-dist: 0.2783, Time: 31.79s
# Epoch 380, D Loss: -0.2315, G Loss: -0.4829, W-dist: 0.2756, Time: 32.51s
# Epoch 381, D Loss: -0.2415, G Loss: -0.4882, W-dist: 0.2844, Time: 31.88s
# Epoch 382, D Loss: -0.2465, G Loss: -0.4801, W-dist: 0.2865, Time: 31.71s
# Epoch 383, D Loss: -0.2433, G Loss: -0.4954, W-dist: 0.2977, Time: 31.06s
# Epoch 384, D Loss: -0.2337, G Loss: -0.5080, W-dist: 0.2758, Time: 31.69s
# Epoch 385, D Loss: -0.2308, G Loss: -0.5622, W-dist: 0.2794, Time: 31.91s
# Epoch 386, D Loss: -0.2159, G Loss: -0.5609, W-dist: 0.2654, Time: 31.11s
# Epoch 387, D Loss: -0.2237, G Loss: -0.5508, W-dist: 0.2697, Time: 32.12s
# Epoch 388, D Loss: -0.2349, G Loss: -0.5072, W-dist: 0.2806, Time: 32.41s
# Epoch 389, D Loss: -0.2280, G Loss: -0.4916, W-dist: 0.2795, Time: 31.00s
# Epoch 390, D Loss: -0.2334, G Loss: -0.5096, W-dist: 0.2842, Time: 31.99s
# Epoch 391, D Loss: -0.2208, G Loss: -0.5216, W-dist: 0.2727, Time: 31.52s
# Epoch 392, D Loss: -0.2267, G Loss: -0.5795, W-dist: 0.2789, Time: 31.37s
# Epoch 393, D Loss: -0.2280, G Loss: -0.6558, W-dist: 0.2855, Time: 32.59s
# Epoch 394, D Loss: -0.2112, G Loss: -0.7004, W-dist: 0.2702, Time: 32.49s
# Epoch 395, D Loss: -0.2246, G Loss: -0.7622, W-dist: 0.2755, Time: 40.94s
# Epoch 396, D Loss: -0.2288, G Loss: -0.8094, W-dist: 0.2831, Time: 33.80s
# Epoch 397, D Loss: -0.2184, G Loss: -0.8247, W-dist: 0.2749, Time: 32.89s
# Epoch 398, D Loss: -0.2242, G Loss: -0.8496, W-dist: 0.2805, Time: 33.31s
# Epoch 399, D Loss: -0.2223, G Loss: -0.9025, W-dist: 0.2784, Time: 31.82s
# Epoch 400, D Loss: -0.2039, G Loss: -0.9624, W-dist: 0.2608, Time: 32.67s
# Epoch 401, D Loss: -0.2057, G Loss: -0.9515, W-dist: 0.2610, Time: 32.32s
# Epoch 402, D Loss: -0.2156, G Loss: -0.9180, W-dist: 0.2705, Time: 31.53s
# Epoch 403, D Loss: -0.2121, G Loss: -0.8796, W-dist: 0.2644, Time: 31.80s
# Epoch 404, D Loss: -0.2364, G Loss: -0.8773, W-dist: 0.2920, Time: 32.68s
# Epoch 405, D Loss: -0.2265, G Loss: -0.8577, W-dist: 0.2779, Time: 31.34s
# Epoch 406, D Loss: -0.2259, G Loss: -0.8602, W-dist: 0.2743, Time: 32.27s
# Epoch 407, D Loss: -0.2296, G Loss: -0.8545, W-dist: 0.2843, Time: 32.06s
# Epoch 408, D Loss: -0.2190, G Loss: -0.9214, W-dist: 0.2815, Time: 40.94s
# Epoch 409, D Loss: -0.2183, G Loss: -0.9343, W-dist: 0.2674, Time: 32.13s
# Epoch 410, D Loss: -0.2278, G Loss: -0.9411, W-dist: 0.2789, Time: 31.58s
# Epoch 411, D Loss: -0.2295, G Loss: -0.9320, W-dist: 0.2754, Time: 31.10s
# Epoch 412, D Loss: -0.2350, G Loss: -0.8595, W-dist: 0.2794, Time: 32.31s
# Epoch 413, D Loss: -0.2099, G Loss: -0.8232, W-dist: 0.2570, Time: 30.86s
# Epoch 414, D Loss: -0.2257, G Loss: -0.7682, W-dist: 0.2699, Time: 31.08s
# Epoch 415, D Loss: -0.2271, G Loss: -0.7579, W-dist: 0.2693, Time: 31.44s
# Epoch 416, D Loss: -0.2270, G Loss: -0.6969, W-dist: 0.2729, Time: 30.54s
# Epoch 417, D Loss: -0.2362, G Loss: -0.6685, W-dist: 0.2778, Time: 31.67s
# Epoch 418, D Loss: -0.2324, G Loss: -0.6522, W-dist: 0.2709, Time: 31.03s
# Epoch 419, D Loss: -0.2326, G Loss: -0.6614, W-dist: 0.2759, Time: 30.42s
# Epoch 420, D Loss: -0.2257, G Loss: -0.6255, W-dist: 0.2654, Time: 31.15s
# Epoch 421, D Loss: -0.2276, G Loss: -0.6357, W-dist: 0.2760, Time: 31.11s
# Epoch 422, D Loss: -0.2214, G Loss: -0.6067, W-dist: 0.2680, Time: 31.10s
# Epoch 423, D Loss: -0.2192, G Loss: -0.5841, W-dist: 0.2675, Time: 31.23s
# Epoch 424, D Loss: -0.2193, G Loss: -0.5569, W-dist: 0.2576, Time: 30.71s
# Epoch 425, D Loss: -0.2124, G Loss: -0.5324, W-dist: 0.2530, Time: 31.13s
# Epoch 426, D Loss: -0.2215, G Loss: -0.5320, W-dist: 0.2614, Time: 30.72s
# Epoch 427, D Loss: -0.2295, G Loss: -0.4807, W-dist: 0.2697, Time: 40.94s
# Epoch 428, D Loss: -0.2211, G Loss: -0.4341, W-dist: 0.2611, Time: 31.48s
# Epoch 429, D Loss: -0.2082, G Loss: -0.4158, W-dist: 0.2484, Time: 31.50s
# Epoch 430, D Loss: -0.2246, G Loss: -0.4225, W-dist: 0.2641, Time: 31.48s
# Epoch 431, D Loss: -0.2075, G Loss: -0.4023, W-dist: 0.2447, Time: 40.94s
# Epoch 432, D Loss: -0.2251, G Loss: -0.3699, W-dist: 0.2666, Time: 31.37s
# Epoch 433, D Loss: -0.1944, G Loss: -0.3468, W-dist: 0.2359, Time: 31.48s
# Epoch 434, D Loss: -0.2058, G Loss: -0.3254, W-dist: 0.2478, Time: 30.85s
# Epoch 435, D Loss: -0.2119, G Loss: -0.3205, W-dist: 0.2509, Time: 31.04s
# Epoch 436, D Loss: -0.2114, G Loss: -0.2803, W-dist: 0.2550, Time: 30.74s
# Epoch 437, D Loss: -0.2091, G Loss: -0.2667, W-dist: 0.2471, Time: 31.82s
# Epoch 438, D Loss: -0.2110, G Loss: -0.2788, W-dist: 0.2525, Time: 40.94s
# Epoch 439, D Loss: -0.2013, G Loss: -0.2795, W-dist: 0.2445, Time: 31.51s
# Epoch 440, D Loss: -0.2250, G Loss: -0.2811, W-dist: 0.2660, Time: 31.64s
# Epoch 441, D Loss: -0.1870, G Loss: -0.2741, W-dist: 0.2317, Time: 40.94s
# Epoch 442, D Loss: -0.2082, G Loss: -0.2330, W-dist: 0.2539, Time: 31.50s
# Epoch 443, D Loss: -0.1901, G Loss: -0.2103, W-dist: 0.2317, Time: 31.39s
# Epoch 444, D Loss: -0.1989, G Loss: -0.1877, W-dist: 0.2409, Time: 30.78s
# Epoch 445, D Loss: -0.2062, G Loss: -0.1520, W-dist: 0.2525, Time: 40.94s
# Epoch 446, D Loss: -0.2040, G Loss: -0.1306, W-dist: 0.2476, Time: 31.04s
# Epoch 447, D Loss: -0.2098, G Loss: -0.1269, W-dist: 0.2576, Time: 31.89s
# Epoch 448, D Loss: -0.2178, G Loss: -0.1250, W-dist: 0.2657, Time: 31.88s
# Epoch 449, D Loss: -0.2135, G Loss: -0.1217, W-dist: 0.2602, Time: 31.26s
# Epoch 450, D Loss: -0.2168, G Loss: -0.1304, W-dist: 0.2738, Time: 32.13s
# Epoch 451, D Loss: -0.1981, G Loss: -0.1135, W-dist: 0.2467, Time: 32.32s
# Epoch 452, D Loss: -0.2046, G Loss: -0.0563, W-dist: 0.2479, Time: 31.54s
# Epoch 453, D Loss: -0.2035, G Loss: -0.0288, W-dist: 0.2444, Time: 32.21s
# Epoch 454, D Loss: -0.2007, G Loss: 0.0034, W-dist: 0.2472, Time: 32.64s
# Epoch 455, D Loss: -0.1976, G Loss: 0.0241, W-dist: 0.2421, Time: 31.40s
# Epoch 456, D Loss: -0.2034, G Loss: -0.0064, W-dist: 0.2477, Time: 31.93s
# Epoch 457, D Loss: -0.2163, G Loss: 0.0079, W-dist: 0.2602, Time: 31.76s
# Epoch 458, D Loss: -0.1601, G Loss: 0.0147, W-dist: 0.2039, Time: 30.86s
# Epoch 459, D Loss: -0.1786, G Loss: 0.0233, W-dist: 0.2234, Time: 31.25s
# Epoch 460, D Loss: -0.1866, G Loss: -0.0047, W-dist: 0.2255, Time: 31.49s
# Epoch 461, D Loss: -0.1759, G Loss: -0.0805, W-dist: 0.2250, Time: 32.41s
# Epoch 462, D Loss: -0.1702, G Loss: -0.0900, W-dist: 0.2203, Time: 33.87s
# Epoch 463, D Loss: -0.1623, G Loss: -0.1287, W-dist: 0.2120, Time: 33.08s
# Epoch 464, D Loss: -0.1703, G Loss: -0.1836, W-dist: 0.2280, Time: 33.65s
# Epoch 465, D Loss: -0.1469, G Loss: -0.2485, W-dist: 0.2065, Time: 33.52s
# Epoch 466, D Loss: -0.1687, G Loss: -0.2754, W-dist: 0.2246, Time: 40.94s
# Epoch 467, D Loss: -0.1555, G Loss: -0.3499, W-dist: 0.2155, Time: 33.32s
# Epoch 468, D Loss: -0.1678, G Loss: -0.3922, W-dist: 0.2292, Time: 33.42s
# Epoch 469, D Loss: -0.1609, G Loss: -0.4470, W-dist: 0.2100, Time: 32.47s
# Epoch 470, D Loss: -0.1755, G Loss: -0.4608, W-dist: 0.2293, Time: 32.95s
# Epoch 471, D Loss: -0.1673, G Loss: -0.4489, W-dist: 0.2114, Time: 33.77s
# Epoch 472, D Loss: -0.1448, G Loss: -0.3730, W-dist: 0.1934, Time: 33.43s
# Epoch 473, D Loss: -0.1727, G Loss: -0.3326, W-dist: 0.2082, Time: 32.43s
# Epoch 474, D Loss: -0.1799, G Loss: -0.3376, W-dist: 0.2156, Time: 32.93s
# Epoch 475, D Loss: -0.1721, G Loss: -0.3466, W-dist: 0.2151, Time: 32.36s
# Epoch 476, D Loss: -0.1519, G Loss: -0.3862, W-dist: 0.1935, Time: 40.94s
# Epoch 477, D Loss: -0.1668, G Loss: -0.3360, W-dist: 0.2031, Time: 31.78s
# Epoch 478, D Loss: -0.1700, G Loss: -0.2908, W-dist: 0.2043, Time: 31.82s
# Epoch 479, D Loss: -0.1757, G Loss: -0.2621, W-dist: 0.2076, Time: 32.25s
# Epoch 480, D Loss: -0.1659, G Loss: -0.2424, W-dist: 0.1985, Time: 32.07s
# Epoch 481, D Loss: -0.1602, G Loss: -0.1907, W-dist: 0.1925, Time: 31.70s
# Epoch 482, D Loss: -0.1422, G Loss: -0.1481, W-dist: 0.1867, Time: 31.10s
# Epoch 483, D Loss: -0.1329, G Loss: -0.1431, W-dist: 0.1727, Time: 31.73s
# Epoch 484, D Loss: -0.1328, G Loss: -0.1419, W-dist: 0.1766, Time: 32.20s
# Epoch 485, D Loss: -0.1289, G Loss: -0.1759, W-dist: 0.1690, Time: 31.58s
# Epoch 486, D Loss: -0.1450, G Loss: -0.1638, W-dist: 0.1854, Time: 32.14s
# Epoch 487, D Loss: -0.1249, G Loss: -0.1681, W-dist: 0.1629, Time: 32.00s
# Epoch 488, D Loss: -0.1274, G Loss: -0.1271, W-dist: 0.1685, Time: 32.50s
# Epoch 489, D Loss: -0.1327, G Loss: -0.0965, W-dist: 0.1770, Time: 31.97s
# Epoch 490, D Loss: -0.1523, G Loss: -0.0590, W-dist: 0.1935, Time: 32.13s
# Epoch 491, D Loss: -0.1156, G Loss: 0.0034, W-dist: 0.1622, Time: 31.06s
# Epoch 492, D Loss: -0.1329, G Loss: 0.0061, W-dist: 0.1814, Time: 31.43s
# Epoch 493, D Loss: -0.1294, G Loss: 0.0522, W-dist: 0.1826, Time: 32.14s
# Epoch 494, D Loss: -0.1542, G Loss: 0.0802, W-dist: 0.2065, Time: 31.46s
# Epoch 495, D Loss: -0.1631, G Loss: 0.0955, W-dist: 0.2143, Time: 31.99s
# Epoch 496, D Loss: -0.1619, G Loss: 0.0381, W-dist: 0.2152, Time: 32.28s
# Epoch 497, D Loss: -0.1371, G Loss: 0.0467, W-dist: 0.1876, Time: 32.06s
# Epoch 498, D Loss: -0.1240, G Loss: 0.0020, W-dist: 0.1718, Time: 32.24s
# Epoch 499, D Loss: -0.0917, G Loss: -0.0013, W-dist: 0.1392, Time: 32.02s
# Epoch 500, D Loss: -0.0939, G Loss: -0.0247, W-dist: 0.1432, Time: 40.94s
# Epoch 501, D Loss: -0.1005, G Loss: -0.0623, W-dist: 0.1553, Time: 32.67s
# Epoch 502, D Loss: -0.1093, G Loss: -0.0808, W-dist: 0.1630, Time: 32.27s
# Epoch 503, D Loss: -0.1120, G Loss: -0.1170, W-dist: 0.1645, Time: 31.36s
# Epoch 504, D Loss: -0.0638, G Loss: -0.1156, W-dist: 0.1254, Time: 32.16s
# Epoch 505, D Loss: -0.0470, G Loss: -0.1645, W-dist: 0.1175, Time: 32.13s
# Epoch 506, D Loss: -0.0856, G Loss: -0.1979, W-dist: 0.1672, Time: 32.33s
# Epoch 507, D Loss: -0.1082, G Loss: -0.2998, W-dist: 0.2012, Time: 32.28s
# Epoch 508, D Loss: -0.1114, G Loss: -0.4539, W-dist: 0.1993, Time: 31.88s
# Epoch 509, D Loss: -0.1101, G Loss: -0.6113, W-dist: 0.1768, Time: 40.94s
# Epoch 510, D Loss: -0.0930, G Loss: -0.7382, W-dist: 0.1648, Time: 32.42s
# Epoch 511, D Loss: -0.1045, G Loss: -0.8219, W-dist: 0.1780, Time: 32.00s
# Epoch 512, D Loss: -0.1721, G Loss: -0.8973, W-dist: 0.2507, Time: 31.82s
# Epoch 513, D Loss: -0.2646, G Loss: -0.9590, W-dist: 0.3438, Time: 32.25s
# Epoch 514, D Loss: -0.2932, G Loss: -1.0180, W-dist: 0.3710, Time: 32.21s
# Epoch 515, D Loss: -0.2619, G Loss: -1.1156, W-dist: 0.3288, Time: 32.51s
# Epoch 516, D Loss: -0.1946, G Loss: -1.1617, W-dist: 0.2560, Time: 31.86s
# Epoch 517, D Loss: -0.1767, G Loss: -1.1940, W-dist: 0.2406, Time: 32.36s
# Epoch 518, D Loss: -0.2777, G Loss: -1.1648, W-dist: 0.3446, Time: 32.40s
# Epoch 519, D Loss: -0.3686, G Loss: -1.0822, W-dist: 0.4384, Time: 31.64s
# Epoch 520, D Loss: -0.4111, G Loss: -1.0314, W-dist: 0.4635, Time: 32.80s
# Epoch 521, D Loss: -0.3799, G Loss: -1.0230, W-dist: 0.4243, Time: 32.18s
# Epoch 522, D Loss: -0.3260, G Loss: -1.0899, W-dist: 0.3675, Time: 31.25s
# Epoch 523, D Loss: -0.2842, G Loss: -1.1308, W-dist: 0.3264, Time: 32.36s
# Epoch 524, D Loss: -0.2259, G Loss: -1.2552, W-dist: 0.2742, Time: 32.54s
# Epoch 525, D Loss: -0.1833, G Loss: -1.3756, W-dist: 0.2312, Time: 40.94s
# Epoch 526, D Loss: -0.1787, G Loss: -1.5621, W-dist: 0.2260, Time: 32.18s
# Epoch 527, D Loss: -0.1863, G Loss: -1.7888, W-dist: 0.2415, Time: 32.02s
# Epoch 528, D Loss: -0.2238, G Loss: -1.9910, W-dist: 0.2776, Time: 31.74s
# Epoch 529, D Loss: -0.2355, G Loss: -2.1478, W-dist: 0.2847, Time: 32.28s
# Epoch 530, D Loss: -0.2302, G Loss: -2.1590, W-dist: 0.2741, Time: 32.17s
# Epoch 531, D Loss: -0.1833, G Loss: -2.0658, W-dist: 0.2340, Time: 31.70s
# Epoch 532, D Loss: -0.1207, G Loss: -1.9040, W-dist: 0.1579, Time: 32.13s
# Epoch 533, D Loss: -0.1157, G Loss: -1.6412, W-dist: 0.1544, Time: 32.75s
# Epoch 534, D Loss: -0.1350, G Loss: -1.3560, W-dist: 0.1650, Time: 40.94s
# Epoch 535, D Loss: -0.1693, G Loss: -1.1113, W-dist: 0.1945, Time: 31.95s
# Epoch 536, D Loss: -0.1793, G Loss: -0.9205, W-dist: 0.2034, Time: 31.91s
# Epoch 537, D Loss: -0.1881, G Loss: -0.6757, W-dist: 0.2132, Time: 31.19s
# Epoch 538, D Loss: -0.1931, G Loss: -0.6232, W-dist: 0.2161, Time: 31.42s
# Epoch 539, D Loss: -0.1758, G Loss: -0.5954, W-dist: 0.1957, Time: 40.94s
# Epoch 540, D Loss: -0.1484, G Loss: -0.5899, W-dist: 0.1735, Time: 31.60s
# Epoch 541, D Loss: -0.1609, G Loss: -0.5699, W-dist: 0.1860, Time: 31.67s
# Epoch 542, D Loss: -0.1667, G Loss: -0.5957, W-dist: 0.1943, Time: 31.45s
# Epoch 543, D Loss: -0.1715, G Loss: -0.5588, W-dist: 0.1987, Time: 31.39s
# Epoch 544, D Loss: -0.1859, G Loss: -0.4858, W-dist: 0.2110, Time: 31.55s
# Epoch 545, D Loss: -0.1854, G Loss: -0.4515, W-dist: 0.2098, Time: 31.12s
# Epoch 546, D Loss: -0.1676, G Loss: -0.3753, W-dist: 0.1923, Time: 31.36s
# Epoch 547, D Loss: -0.1681, G Loss: -0.2818, W-dist: 0.1928, Time: 40.94s
# Epoch 548, D Loss: -0.1647, G Loss: -0.1993, W-dist: 0.1875, Time: 31.65s
# Epoch 549, D Loss: -0.1826, G Loss: -0.1548, W-dist: 0.2045, Time: 31.49s
# Epoch 550, D Loss: -0.1699, G Loss: -0.1343, W-dist: 0.1934, Time: 31.16s
# Epoch 551, D Loss: -0.1703, G Loss: -0.1398, W-dist: 0.1908, Time: 31.34s
# Epoch 552, D Loss: -0.1647, G Loss: -0.1403, W-dist: 0.1840, Time: 32.13s
# Epoch 553, D Loss: -0.1619, G Loss: -0.1582, W-dist: 0.1816, Time: 31.37s
# Epoch 554, D Loss: -0.1593, G Loss: -0.1777, W-dist: 0.1780, Time: 31.80s
# Epoch 555, D Loss: -0.1457, G Loss: -0.1593, W-dist: 0.1684, Time: 40.94s
# Epoch 556, D Loss: -0.1525, G Loss: -0.1524, W-dist: 0.1749, Time: 31.86s
# Epoch 557, D Loss: -0.1331, G Loss: -0.1417, W-dist: 0.1548, Time: 31.57s
# Epoch 558, D Loss: -0.1387, G Loss: -0.1317, W-dist: 0.1607, Time: 31.12s
# Epoch 559, D Loss: -0.1360, G Loss: -0.1382, W-dist: 0.1575, Time: 31.66s
# Epoch 560, D Loss: -0.1281, G Loss: -0.1227, W-dist: 0.1494, Time: 31.76s
# Epoch 561, D Loss: -0.1330, G Loss: -0.1179, W-dist: 0.1517, Time: 31.81s
# Epoch 562, D Loss: -0.1229, G Loss: -0.1422, W-dist: 0.1526, Time: 31.57s
# Epoch 563, D Loss: -0.1068, G Loss: -0.1683, W-dist: 0.1302, Time: 31.74s
# Epoch 564, D Loss: -0.1172, G Loss: -0.1704, W-dist: 0.1404, Time: 31.20s
# Epoch 565, D Loss: -0.1010, G Loss: -0.2117, W-dist: 0.1267, Time: 31.59s
# Epoch 566, D Loss: -0.1037, G Loss: -0.2358, W-dist: 0.1258, Time: 31.95s
# Epoch 567, D Loss: -0.1127, G Loss: -0.2585, W-dist: 0.1347, Time: 31.02s
# Epoch 568, D Loss: -0.0922, G Loss: -0.3243, W-dist: 0.1152, Time: 31.49s
# Epoch 569, D Loss: -0.0860, G Loss: -0.3695, W-dist: 0.1095, Time: 40.94s
# Epoch 570, D Loss: -0.0862, G Loss: -0.3987, W-dist: 0.1131, Time: 31.75s
# Epoch 571, D Loss: -0.0879, G Loss: -0.3525, W-dist: 0.1123, Time: 32.70s
# Epoch 572, D Loss: -0.0710, G Loss: -0.3269, W-dist: 0.0978, Time: 31.80s
# Epoch 573, D Loss: -0.0793, G Loss: -0.3513, W-dist: 0.1098, Time: 31.93s
# Epoch 574, D Loss: -0.0699, G Loss: -0.3167, W-dist: 0.0947, Time: 32.43s
# Epoch 575, D Loss: -0.0741, G Loss: -0.3391, W-dist: 0.1031, Time: 40.94s
# Epoch 576, D Loss: -0.0769, G Loss: -0.4010, W-dist: 0.1077, Time: 31.93s
# Epoch 577, D Loss: -0.0648, G Loss: -0.5010, W-dist: 0.0961, Time: 32.30s
# Epoch 578, D Loss: -0.0899, G Loss: -0.5485, W-dist: 0.1182, Time: 32.10s
# Epoch 579, D Loss: -0.0712, G Loss: -0.4782, W-dist: 0.0996, Time: 32.44s
# Epoch 580, D Loss: -0.0627, G Loss: -0.3964, W-dist: 0.0938, Time: 33.19s
# Epoch 581, D Loss: -0.0547, G Loss: -0.3901, W-dist: 0.0821, Time: 32.42s
# Epoch 582, D Loss: -0.0642, G Loss: -0.4353, W-dist: 0.0904, Time: 31.78s
# Epoch 583, D Loss: -0.0480, G Loss: -0.4106, W-dist: 0.0790, Time: 32.47s
# Epoch 584, D Loss: -0.0297, G Loss: -0.4444, W-dist: 0.0610, Time: 32.33s
# Epoch 585, D Loss: -0.0605, G Loss: -0.4976, W-dist: 0.0850, Time: 31.98s
# Epoch 586, D Loss: -0.0341, G Loss: -0.5269, W-dist: 0.0651, Time: 31.82s
# Epoch 587, D Loss: -0.0418, G Loss: -0.5993, W-dist: 0.0694, Time: 31.70s
# Epoch 588, D Loss: -0.0013, G Loss: -0.6135, W-dist: 0.0346, Time: 31.38s
# Epoch 589, D Loss: -0.0155, G Loss: -0.5394, W-dist: 0.0452, Time: 31.85s
# Epoch 590, D Loss: -0.0102, G Loss: -0.4645, W-dist: 0.0420, Time: 32.58s
# Epoch 591, D Loss: -0.0135, G Loss: -0.4433, W-dist: 0.0472, Time: 31.39s
# Epoch 592, D Loss: 0.0159, G Loss: -0.4414, W-dist: 0.0160, Time: 31.96s
# Epoch 593, D Loss: 0.0395, G Loss: -0.4880, W-dist: -0.0049, Time: 32.90s
# Epoch 594, D Loss: 0.0174, G Loss: -0.5514, W-dist: 0.0166, Time: 33.87s
# Epoch 595, D Loss: 0.0194, G Loss: -0.6589, W-dist: 0.0197, Time: 32.52s
# Epoch 596, D Loss: 0.0286, G Loss: -0.6564, W-dist: 0.0128, Time: 33.88s
# Epoch 597, D Loss: 0.0351, G Loss: -0.6259, W-dist: 0.0044, Time: 33.24s
# Epoch 598, D Loss: 0.0518, G Loss: -0.5735, W-dist: -0.0077, Time: 33.01s
# Epoch 599, D Loss: 0.0213, G Loss: -0.4350, W-dist: 0.0187, Time: 34.05s
# Epoch 600, D Loss: 0.0113, G Loss: -0.3423, W-dist: 0.0269, Time: 34.44s
# Training finished.

# %%
import matplotlib.pyplot as plt

def plot_loss_curves(d_losses, g_losses, w_distances):
    """
    Visualizes the loss curves of the Discriminator, Generator, and Wasserstein Distance.

    Parameters:
    - d_loss_hist: List of discriminator loss values
    - g_loss_hist: List of generator loss values
    - wasserstein_hist: List of Wasserstein distance values
    """
    plt.figure(figsize=(12, 5))

    # Subplot 1: Discriminator and Generator Losses
    plt.subplot(1, 2, 1)
    plt.plot(d_loss_hist, label='Discriminator Loss', color='r')
    plt.plot(g_loss_hist, label='Generator Loss', color='b')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Discriminator and Generator Losses')
    plt.legend()
    plt.grid(True)

    # Subplot 2: Wasserstein Distance
    plt.subplot(1, 2, 2)
    plt.plot(wasserstein_hist, label='Wasserstein Distance', color='purple')
    plt.xlabel('Epoch')
    plt.ylabel('W-Distance')
    plt.title('Wasserstein Distance Over Time')
    plt.legend()
    plt.grid(True)

    # Tight layout for better spacing
    plt.tight_layout()
    plt.show()

# %%
# Plot the loss curves
plot_loss_curves(d_loss_hist, g_loss_hist, wasserstein_hist)

# %%
def generate_synthetic_data(generator, num_samples):
    """
    Generate synthetic data using the trained generator.

    Args:
        generator: Trained generator model.
        num_samples: Number of synthetic sequences to generate.

    Returns:
        synthetic_data: Numpy array of shape (num_samples, SEQ_LEN, FEATURE_DIM)
    """
    noise = tf.random.normal([num_samples, SEQ_LEN, LATENT_DIM])
    synthetic_data = generator(noise, training=False).numpy()
    return synthetic_data

# %%
num_samples = 1000
synthetic_samples = generate_synthetic_data(generator, num_samples)

# %%
synthetic_samples
# Out:
# array([[[ 0.37327102,  0.5724592 ,  0.44078398],
#         [ 0.1074276 ,  0.1780503 ,  0.13673085],
#         [ 0.250825  ,  0.25592878,  0.21476835],
#         ...,
#         [ 0.31163076,  0.10783651,  0.1675233 ],
#         [ 0.13644932, -0.01083497, -0.04410384],
#         [ 0.14909993,  0.22260547, -0.03774201]],
#
#        [[ 0.39761934,  0.5243011 ,  0.41953734],
#         [ 0.4443052 ,  0.5036328 ,  0.3769472 ],
#         [ 0.29291978,  0.27953646,  0.2086082 ],
#         ...,
#         [ 0.3539244 ,  0.2501461 ,  0.33532053],
#         [ 0.28436852,  0.27795532,  0.2709606 ],
#         [ 0.2200388 ,  0.25179937,  0.25472954]],
#
#        [[ 0.28239468,  0.3866878 ,  0.3319498 ],
#         [ 0.41005877,  0.52725554,  0.34801456],
#         [ 0.5151068 ,  0.49547407,  0.37260774],
#         ...,
#         [ 0.3286317 ,  0.18663076,  0.2867618 ],
#         [ 0.42754295,  0.38073343,  0.4551259 ],
#         [ 0.56904525,  0.88725847,  0.53903735]],
#
#        ...,
#
#        [[ 0.14184186,  0.23844722,  0.25280088],
#         [ 0.11462538,  0.04626592,  0.21298483],
#         [ 0.13596314,  0.01004534,  0.17218891],
#         ...,
#         [ 0.18231322,  0.21332183,  0.05467135],
#         [ 0.18652926,  0.2143636 ,  0.04593737],
#         [ 0.15457952,  0.35909906, -0.12518191]],
#
#        [[ 0.54107696,  0.5970189 ,  0.61931   ],
#         [ 0.12605782,  0.14480978,  0.16448885],
#         [ 0.23554403,  0.19817144,  0.29581523],
#         ...,
#         [ 0.23380098,  0.34959632,  0.26034075],
#         [ 0.07543797,  0.39971197,  0.17691097],
#         [ 0.01110101,  0.46319717,  0.06215718]],
#
#        [[ 0.22777987,  0.2841799 ,  0.34274808],
#         [ 0.22201265,  0.29680425,  0.2493499 ],
#         [ 0.2986396 ,  0.35280403,  0.26382172],
#         ...,
#         [ 0.29616964,  0.3595629 ,  0.09384406],
#         [ 0.30619198,  0.39790338,  0.02809501],
#         [ 0.22410695,  0.43057957,  0.00214443]]], dtype=float32)

# %% [markdown]
# - Input: a noise sequence of shape (window_length, latent_dim). In practice, we often set window_length=60 (as in prior work) and latent_dim=1.
# - Recurrent layers: Two stacked GRU layers (return_sequences=True) process the input sequence.
# - Dense layers: After the RNN, we apply a TimeDistributed Dense with GELU activation to introduce nonlinearity and speed up convergence
#
# - A final TimeDistributed Dense (no activation) maps to the output features.
# - Output: a synthetic sequence of shape (window_length, output_dim) (e.g. (60,1)), matching the real data shape

# %%
import pandas as pd

# flatten sequence into tabular form
generated_data_flat = synthetic_samples.reshape(-1, len(features))
df_fake = pd.DataFrame(generated_data_flat, columns=features)
# Save to CSV
df_fake.to_csv('generated_data_flat.csv', index=False)

# %%
df_fake
# Out:
#          Value  Value_HeatPump  Value_OtherAppliances
# 0     0.373271        0.572459               0.440784
# 1     0.107428        0.178050               0.136731
# 2     0.250825        0.255929               0.214768
# 3     0.376375        0.264841               0.170573
# 4     0.311631        0.107837               0.167523
# ...        ...             ...                    ...
# 6995  0.298640        0.352804               0.263822
# 6996  0.339911        0.420240               0.269140
# 6997  0.296170        0.359563               0.093844
# 6998  0.306192        0.397903               0.028095
# 6999  0.224107        0.430580               0.002144
#
# [7000 rows x 3 columns]

# %%
# statistical overlap
def evaluate_statistics(sequence_data,synthetic):
    real_flat = sequence_data.reshape(-1, sequence_data.shape[-1])
    fake_flat = synthetic.reshape(-1, synthetic.shape[-1])

    stats = {}
    for i, feature_name in enumerate(features):
        real_mean = np.mean(real_flat[:, i])
        fake_mean = np.mean(fake_flat[:, i])
        real_std = np.std(real_flat[:, i])
        fake_std = np.std(fake_flat[:, i])

        stats[feature_name] = {
            "real_mean": real_mean,
            "fake_mean": fake_mean,
            "real_std": real_std,
            "fake_std": fake_std
        }
    return stats

# %%
# Evaluate
stats = evaluate_statistics(real_sequences, synthetic_samples)
for feat, s in stats.items():
    print(f"{feat}: Real μ={s['real_mean']:.3f}, Fake μ={s['fake_mean']:.3f} | Real σ={s['real_std']:.3f}, Fake σ={s['fake_std']:.3f}")
# Out:
# Value: Real μ=0.359, Fake μ=0.371 | Real σ=0.244, Fake σ=0.280
# Value_HeatPump: Real μ=0.349, Fake μ=0.370 | Real σ=0.229, Fake σ=0.277
# Value_OtherAppliances: Real μ=0.360, Fake μ=0.335 | Real σ=0.251, Fake σ=0.298

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming 'stats' is the output dictionary from evaluate_statistics()
features = list(stats.keys())
real_means = [stats[f]['real_mean'] for f in features]
fake_means = [stats[f]['fake_mean'] for f in features]
real_stds = [stats[f]['real_std'] for f in features]
fake_stds = [stats[f]['fake_std'] for f in features]

x = np.arange(len(features))  # label locations
width = 0.35  # width of the bars

fig, axs = plt.subplots(1, 2, figsize=(14, 5))

# Plot means
axs[0].bar(x - width/2, real_means, width, label='Real', color='skyblue')
axs[0].bar(x + width/2, fake_means, width, label='Synthetic', color='salmon')
axs[0].set_ylabel('Mean')
axs[0].set_title('Mean Comparison per Feature')
axs[0].set_xticks(x)
axs[0].set_xticklabels(features, rotation=45)
axs[0].legend()

# Plot stds
axs[1].bar(x - width/2, real_stds, width, label='Real', color='skyblue')
axs[1].bar(x + width/2, fake_stds, width, label='Synthetic', color='salmon')
axs[1].set_ylabel('Standard Deviation')
axs[1].set_title('Standard Deviation Comparison per Feature')
axs[1].set_xticks(x)
axs[1].set_xticklabels(features, rotation=45)
axs[1].legend()

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Example variable shapes:
# sequence_data: shape (n_samples, seq_len, n_features)
# synthetic: shape (n_samples, seq_len, n_features)

# Assume feature names are in correct order from `stats.keys()`
feature_names = list(stats.keys())

# Reshape from (samples, time, features) to (samples * time, features)
real_reshaped = real_sequences.reshape(-1, real_sequences.shape[2])
synthetic_reshaped = synthetic_samples.reshape(-1, synthetic_samples.shape[2])

# Create DataFrames
real_df = pd.DataFrame(real_reshaped, columns=feature_names)
real_df["Source"] = "Real"

synthetic_df = pd.DataFrame(synthetic_reshaped, columns=feature_names)
synthetic_df["Source"] = "Synthetic"

# Combine for plotting
combined_df = pd.concat([real_df, synthetic_df], axis=0)

# Plot distributions
num_features = len(feature_names)
cols = 3
rows = (num_features + cols - 1) // cols

plt.figure(figsize=(5 * cols, 4 * rows))

for i, feature in enumerate(feature_names):
    plt.subplot(rows, cols, i + 1)
    sns.kdeplot(data=combined_df, x=feature, hue="Source", fill=True, common_norm=False, alpha=0.5)
    plt.title(f"Distribution of {feature}")
    plt.xlabel(feature)
    plt.ylabel("Density")

plt.tight_layout()
plt.show()

# %%
import numpy as np
from scipy.stats import entropy, wasserstein_distance


# === Metric Functions ===
def kl_divergence(p, q):
    p += 1e-8
    q += 1e-8
    return entropy(p, q)

def js_divergence(p, q):
    p += 1e-8
    q += 1e-8
    m = 0.5 * (p + q)
    return 0.5 * (entropy(p, m) + entropy(q, m))

# === Evaluation Function ===
def evaluate_gan_outputs(real_sequences, generated_sequences, feature_names=None):
    if isinstance(real_sequences, tf.Tensor):
        real_sequences = real_sequences.numpy()
    if isinstance(generated_sequences, tf.Tensor):
        generated_sequences = synthetic_samples.numpy()

    real_flat = real_sequences.reshape(-1, real_sequences.shape[-1])
    gen_flat = synthetic_samples.reshape(-1, synthetic_samples.shape[-1])
    n_features = real_flat.shape[-1]

    print("\n📊 RGAN Evaluation Metrics")
    for i in range(n_features):
        real_vals = real_flat[:, i]
        gen_vals = gen_flat[:, i]

        # Histogram for divergence metrics
        # Use density=True for normalized histograms suitable for divergence measures
        bins = np.histogram_bin_edges(np.concatenate([real_vals, gen_vals]), bins="auto")
        real_hist, _ = np.histogram(real_vals, bins=bins, density=True)
        gen_hist, _ = np.histogram(gen_vals, bins=bins, density=True)

        # Although density=True normalizes, explicitly re-normalizing
        # helps handle potential floating point issues and ensures sum is exactly 1.
        real_hist /= (np.sum(real_hist) + 1e-8) # Add small epsilon to avoid division by zero
        gen_hist /= (np.sum(gen_hist) + 1e-8)   # Add small epsilon

        # Metrics
        kl = kl_divergence(real_hist, gen_hist)
        js = js_divergence(real_hist, gen_hist)
        wd = wasserstein_distance(real_vals, gen_vals)

        fname = feature_names[i] if feature_names else f"Feature {i+1}"
        print(f"\n🔹 {fname}")
        print(f"  - KL Divergence        : {kl:.4f}")
        print(f"  - JS Divergence        : {js:.4f}")
        print(f"  - Wasserstein Distance : {wd:.4f}")
        # Removed MSE and MAE output

# %%
evaluate_gan_outputs(
    real_sequences=real_sequences,
    generated_sequences=synthetic_samples,  # Changed 'synthetic_samples' to 'generated_sequences'
    feature_names=["Value", "Value_HeatPump", "Value_OtherAppliances"]
)
# Out:
# 📊 RGAN Evaluation Metrics
#
# 🔹 Value
#   - KL Divergence        : 0.3433
#   - JS Divergence        : 0.0838
#   - Wasserstein Distance : 0.0503
#
# 🔹 Value_HeatPump
#   - KL Divergence        : 0.4967
#   - JS Divergence        : 0.1035
#   - Wasserstein Distance : 0.0665
#
# 🔹 Value_OtherAppliances
#   - KL Divergence        : 0.3047
#   - JS Divergence        : 0.0840
#   - Wasserstein Distance : 0.0503
